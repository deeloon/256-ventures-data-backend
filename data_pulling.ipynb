# %%
import requests
import json
import csv
import os
from datetime import datetime
import pandas as pd
import logging
import boto3
from botocore.exceptions import ClientError

# %% [markdown]
# # Bitmex
# https://www.bitmex.com/api/explorer/#/
#
# use XBTUSD as currency

# %%
r = requests.get('https://www.bitmex.com/api/v1/stats/history')
if r.status_code != 200:
    print(r.status_code)

data = r.json()
filtered_data = [data[i] for i in range(len(data)) if (data[i]['rootSymbol']=='XBT') | (data[i]['rootSymbol']=='ETH')]
filtered_data
# Out:
# [{'date': '2014-11-22T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2,
#   'turnover': 0},
#  {'date': '2014-11-23T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2,
#   'turnover': 0},
#  {'date': '2014-11-24T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 30315,
#   'turnover': 0},
#  {'date': '2014-11-25T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 49220,
#   'turnover': 0},
#  {'date': '2014-11-26T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 29212,
#   'turnover': 0},
#  {'date': '2014-11-27T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 282,
#   'turnover': 0},
#  {'date': '2014-11-28T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 5927,
#   'turnover': 0},
#  {'date': '2014-11-29T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3142,
#   'turnover': 39269000},
#  {'date': '2014-11-30T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1493,
#   'turnover': 0},
#  {'date': '2014-12-01T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 5397,
#   'turnover': 466500450},
#  {'date': '2014-12-02T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 10805,
#   'turnover': 1102611100},
#  {'date': '2014-12-03T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 9478,
#   'turnover': 3019217000},
#  {'date': '2014-12-04T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 41430,
#   'turnover': 9798877800},
#  {'date': '2014-12-05T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 39435,
#   'turnover': 5170555000},
#  {'date': '2014-12-06T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2059,
#   'turnover': 67044660},
#  {'date': '2014-12-07T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 704,
#   'turnover': 78850000},
#  {'date': '2014-12-08T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 46759,
#   'turnover': 14877800450},
#  {'date': '2014-12-09T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 85277,
#   'turnover': 17879326190},
#  {'date': '2014-12-10T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 9302,
#   'turnover': 1862936000},
#  {'date': '2014-12-11T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 11161,
#   'turnover': 421993670},
#  {'date': '2014-12-12T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 52586,
#   'turnover': 1453236170},
#  {'date': '2014-12-13T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 4391,
#   'turnover': 355985740},
#  {'date': '2014-12-14T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2350,
#   'turnover': 330342290},
#  {'date': '2014-12-15T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 35092,
#   'turnover': 3162782260},
#  {'date': '2014-12-16T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 61020,
#   'turnover': 18725170060},
#  {'date': '2014-12-17T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 80407,
#   'turnover': 9883974260},
#  {'date': '2014-12-18T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 67001,
#   'turnover': 9434302610},
#  {'date': '2014-12-19T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 6740,
#   'turnover': 363064420},
#  {'date': '2014-12-20T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 14965,
#   'turnover': 3686660510},
#  {'date': '2014-12-21T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 9027,
#   'turnover': 2362598790},
#  {'date': '2014-12-22T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 21545,
#   'turnover': 3133576890},
#  {'date': '2014-12-23T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 11478,
#   'turnover': 3551378820},
#  {'date': '2014-12-24T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 4989,
#   'turnover': 1064900000},
#  {'date': '2014-12-25T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 5770,
#   'turnover': 759072000},
#  {'date': '2014-12-26T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 26946,
#   'turnover': 318783040},
#  {'date': '2014-12-27T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 25617,
#   'turnover': 6613332950},
#  {'date': '2014-12-28T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3529,
#   'turnover': 348264390},
#  {'date': '2014-12-29T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3799,
#   'turnover': 82037910},
#  {'date': '2014-12-30T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 17137,
#   'turnover': 5092152360},
#  {'date': '2014-12-31T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 4153,
#   'turnover': 695976500},
#  {'date': '2015-01-01T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 5887,
#   'turnover': 496180460},
#  {'date': '2015-01-02T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 7158,
#   'turnover': 560072240},
#  {'date': '2015-01-03T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 18854,
#   'turnover': 2139426600},
#  {'date': '2015-01-04T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 127162,
#   'turnover': 31109261780},
#  {'date': '2015-01-05T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 75387,
#   'turnover': 16615677270},
#  {'date': '2015-01-06T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 88826,
#   'turnover': 27193916610},
#  {'date': '2015-01-07T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 57771,
#   'turnover': 17992437800},
#  {'date': '2015-01-08T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 36372,
#   'turnover': 11444923940},
#  {'date': '2015-01-09T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 28658,
#   'turnover': 8749755810},
#  {'date': '2015-01-10T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 16709,
#   'turnover': 4995821950},
#  {'date': '2015-01-11T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 8435,
#   'turnover': 2395389190},
#  {'date': '2015-01-12T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 27925,
#   'turnover': 8361441280},
#  {'date': '2015-01-13T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 244881,
#   'turnover': 63076472910},
#  {'date': '2015-01-14T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 308084,
#   'turnover': 70270404850},
#  {'date': '2015-01-15T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 148968,
#   'turnover': 34967405890},
#  {'date': '2015-01-16T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 17599,
#   'turnover': 3985443070},
#  {'date': '2015-01-17T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 73867,
#   'turnover': 17304405210},
#  {'date': '2015-01-18T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 22622,
#   'turnover': 5385609000},
#  {'date': '2015-01-19T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 36422,
#   'turnover': 8537401900},
#  {'date': '2015-01-20T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 100935,
#   'turnover': 25027205570},
#  {'date': '2015-01-21T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 65834,
#   'turnover': 16308481130},
#  {'date': '2015-01-22T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 96553,
#   'turnover': 25317852070},
#  {'date': '2015-01-23T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 42089,
#   'turnover': 10396075700},
#  {'date': '2015-01-24T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 19874,
#   'turnover': 4942829570},
#  {'date': '2015-01-25T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 65434,
#   'turnover': 16821219580},
#  {'date': '2015-01-26T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 324751,
#   'turnover': 96433104860},
#  {'date': '2015-01-27T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 63719,
#   'turnover': 17062502800},
#  {'date': '2015-01-28T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 93559,
#   'turnover': 23881569420},
#  {'date': '2015-01-29T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 68627,
#   'turnover': 16877030400},
#  {'date': '2015-01-30T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 141250,
#   'turnover': 34422648720},
#  {'date': '2015-01-31T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 41550,
#   'turnover': 10221102000},
#  {'date': '2015-02-01T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 128658,
#   'turnover': 29497338500},
#  {'date': '2015-02-02T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 17331,
#   'turnover': 4228067620},
#  {'date': '2015-02-03T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 21857,
#   'turnover': 5439330900},
#  {'date': '2015-02-04T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 11954,
#   'turnover': 2854837000},
#  {'date': '2015-02-05T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 11214,
#   'turnover': 2600814030},
#  {'date': '2015-02-06T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 19344,
#   'turnover': 4432765590},
#  {'date': '2015-02-07T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 7611,
#   'turnover': 1799389690},
#  {'date': '2015-02-08T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2007,
#   'turnover': 478144350},
#  {'date': '2015-02-09T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 6572,
#   'turnover': 1512365300},
#  {'date': '2015-02-10T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 9501,
#   'turnover': 2156655000},
#  {'date': '2015-02-11T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3111,
#   'turnover': 720399000},
#  {'date': '2015-02-12T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3405,
#   'turnover': 791888000},
#  {'date': '2015-02-13T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 12235,
#   'turnover': 2969110700},
#  {'date': '2015-02-14T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 20160,
#   'turnover': 5158030770},
#  {'date': '2015-02-15T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 38845,
#   'turnover': 9830875270},
#  {'date': '2015-02-16T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 10063,
#   'turnover': 2466057750},
#  {'date': '2015-02-17T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 5496,
#   'turnover': 1375401090},
#  {'date': '2015-02-18T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 11715,
#   'turnover': 2933949920},
#  {'date': '2015-02-19T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 6800,
#   'turnover': 1668704000},
#  {'date': '2015-02-20T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 10652,
#   'turnover': 2647345500},
#  {'date': '2015-02-21T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 8664,
#   'turnover': 2120485700},
#  {'date': '2015-02-22T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3549,
#   'turnover': 824657970},
#  {'date': '2015-02-23T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3100,
#   'turnover': 739235000},
#  {'date': '2015-02-24T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2756,
#   'turnover': 673605040},
#  {'date': '2015-02-25T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2500,
#   'turnover': 609420000},
#  {'date': '2015-02-26T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1500,
#   'turnover': 359405000},
#  {'date': '2015-02-27T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 69734,
#   'turnover': 17740679310},
#  {'date': '2015-02-28T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 500,
#   'turnover': 131500000},
#  {'date': '2015-03-01T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 23385,
#   'turnover': 6134491000},
#  {'date': '2015-03-02T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 38726,
#   'turnover': 10916812420},
#  {'date': '2015-03-03T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 27344,
#   'turnover': 7957919390},
#  {'date': '2015-03-04T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 19548,
#   'turnover': 5417115470},
#  {'date': '2015-03-05T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3932,
#   'turnover': 1084551210},
#  {'date': '2015-03-06T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3521,
#   'turnover': 994462230},
#  {'date': '2015-03-07T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1131,
#   'turnover': 321920000},
#  {'date': '2015-03-08T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1000,
#   'turnover': 286500000},
#  {'date': '2015-03-09T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 23896,
#   'turnover': 7087924450},
#  {'date': '2015-03-10T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 31604,
#   'turnover': 9611930680},
#  {'date': '2015-03-11T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 6450,
#   'turnover': 1950049850},
#  {'date': '2015-03-12T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3735,
#   'turnover': 1128836250},
#  {'date': '2015-03-13T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 5155,
#   'turnover': 1525957550},
#  {'date': '2015-03-14T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 4770,
#   'turnover': 1385337500},
#  {'date': '2015-03-15T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 450,
#   'turnover': 131606000},
#  {'date': '2015-03-16T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1281,
#   'turnover': 383936950},
#  {'date': '2015-03-17T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1000,
#   'turnover': 296005000},
#  {'date': '2015-03-18T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 31062,
#   'turnover': 8512772240},
#  {'date': '2015-03-19T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 4507,
#   'turnover': 1160918990},
#  {'date': '2015-03-20T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 4751,
#   'turnover': 1249961470},
#  {'date': '2015-03-21T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2000,
#   'turnover': 523135000},
#  {'date': '2015-03-22T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1420,
#   'turnover': 374652400},
#  {'date': '2015-03-23T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 6706,
#   'turnover': 1818270300},
#  {'date': '2015-03-24T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3667,
#   'turnover': 921851280},
#  {'date': '2015-03-25T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 14416,
#   'turnover': 3538483970},
#  {'date': '2015-03-26T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 9833,
#   'turnover': 2470909500},
#  {'date': '2015-03-27T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 756842,
#   'turnover': 187402142200},
#  {'date': '2015-03-28T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 19618,
#   'turnover': 4961776280},
#  {'date': '2015-03-29T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 33703,
#   'turnover': 8401667420},
#  {'date': '2015-03-30T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 12454,
#   'turnover': 3082561580},
#  {'date': '2015-03-31T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 5400,
#   'turnover': 1349198000},
#  {'date': '2015-04-01T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 9300,
#   'turnover': 2297125000},
#  {'date': '2015-04-02T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 10896,
#   'turnover': 2757575730},
#  {'date': '2015-04-03T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3496,
#   'turnover': 907720870},
#  {'date': '2015-04-04T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1501,
#   'turnover': 385754010},
#  {'date': '2015-04-05T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 50273,
#   'turnover': 13414552510},
#  {'date': '2015-04-06T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 11545,
#   'turnover': 3093116520},
#  {'date': '2015-04-07T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1700,
#   'turnover': 443184000},
#  {'date': '2015-04-08T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 19584,
#   'turnover': 4951037330},
#  {'date': '2015-04-09T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 5910,
#   'turnover': 1468106000},
#  {'date': '2015-04-10T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 12310,
#   'turnover': 2977890840},
#  {'date': '2015-04-11T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1755,
#   'turnover': 423933220},
#  {'date': '2015-04-12T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 501,
#   'turnover': 120240100},
#  {'date': '2015-04-13T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 10265,
#   'turnover': 2384254850},
#  {'date': '2015-04-14T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 17679,
#   'turnover': 3952000640},
#  {'date': '2015-04-15T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1862,
#   'turnover': 418709520},
#  {'date': '2015-04-16T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 9247,
#   'turnover': 2142559330},
#  {'date': '2015-04-17T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3240,
#   'turnover': 722419500},
#  {'date': '2015-04-18T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1944,
#   'turnover': 434747350},
#  {'date': '2015-04-19T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 997,
#   'turnover': 226578250},
#  {'date': '2015-04-20T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2100,
#   'turnover': 473146000},
#  {'date': '2015-04-21T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 7532,
#   'turnover': 1776912510},
#  {'date': '2015-04-22T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1931,
#   'turnover': 462245450},
#  {'date': '2015-04-23T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 100,
#   'turnover': 24350000},
#  {'date': '2015-04-24T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 56793,
#   'turnover': 13150102840},
#  {'date': '2015-04-25T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2528,
#   'turnover': 590365950},
#  {'date': '2015-04-26T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 6287,
#   'turnover': 1408930780},
#  {'date': '2015-04-27T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 8636,
#   'turnover': 1976933240},
#  {'date': '2015-04-28T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1392,
#   'turnover': 321822290},
#  {'date': '2015-04-29T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 912,
#   'turnover': 211447510},
#  {'date': '2015-04-30T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 7956,
#   'turnover': 1911222650},
#  {'date': '2015-05-01T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1625,
#   'turnover': 395580000},
#  {'date': '2015-05-02T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 644,
#   'turnover': 152850080},
#  {'date': '2015-05-03T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3147,
#   'turnover': 776558190},
#  {'date': '2015-05-04T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 19190,
#   'turnover': 4862858480},
#  {'date': '2015-05-05T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 29785,
#   'turnover': 7293530010},
#  {'date': '2015-05-06T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3077,
#   'turnover': 739789060},
#  {'date': '2015-05-07T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2495,
#   'turnover': 613443130},
#  {'date': '2015-05-08T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3636,
#   'turnover': 914676410},
#  {'date': '2015-05-09T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2373,
#   'turnover': 589149540},
#  {'date': '2015-05-10T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 4112,
#   'turnover': 1024058500},
#  {'date': '2015-05-11T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1150,
#   'turnover': 286408560},
#  {'date': '2015-05-12T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1233,
#   'turnover': 308017960},
#  {'date': '2015-05-13T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 4538,
#   'turnover': 1149684360},
#  {'date': '2015-05-14T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3032,
#   'turnover': 732548780},
#  {'date': '2015-05-15T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1000,
#   'turnover': 241330000},
#  {'date': '2015-05-16T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 40,
#   'turnover': 9619200},
#  {'date': '2015-05-17T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3,
#   'turnover': 728100},
#  {'date': '2015-05-18T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3903,
#   'turnover': 940248180},
#  {'date': '2015-05-19T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 6582,
#   'turnover': 1561958400},
#  {'date': '2015-05-20T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 9838,
#   'turnover': 2346544530},
#  {'date': '2015-05-21T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 13002,
#   'turnover': 3118892060},
#  {'date': '2015-05-22T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2714,
#   'turnover': 653502220},
#  {'date': '2015-05-23T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 220,
#   'turnover': 53170000},
#  {'date': '2015-05-24T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 10177,
#   'turnover': 2451939000},
#  {'date': '2015-05-25T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1927,
#   'turnover': 467346000},
#  {'date': '2015-05-26T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 274,
#   'turnover': 65291800},
#  {'date': '2015-05-27T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 786,
#   'turnover': 188471000},
#  {'date': '2015-05-28T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 136,
#   'turnover': 32304810},
#  {'date': '2015-05-29T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 14220,
#   'turnover': 3363988840},
#  {'date': '2015-05-30T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1200,
#   'turnover': 298368000},
#  {'date': '2015-05-31T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 6318,
#   'turnover': 1607413700},
#  {'date': '2015-06-01T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 8973,
#   'turnover': 2155561770},
#  {'date': '2015-06-02T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3444,
#   'turnover': 810405410},
#  {'date': '2015-06-03T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 7958,
#   'turnover': 1829707580},
#  {'date': '2015-06-04T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 10831,
#   'turnover': 2549553380},
#  {'date': '2015-06-05T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2000,
#   'turnover': 455962000},
#  {'date': '2015-06-06T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 126,
#   'turnover': 28582000},
#  {'date': '2015-06-07T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1974,
#   'turnover': 470598000},
#  {'date': '2015-06-08T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 6903,
#   'turnover': 1621133130},
#  {'date': '2015-06-09T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2796,
#   'turnover': 657217080},
#  {'date': '2015-06-10T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2029,
#   'turnover': 465967670},
#  {'date': '2015-06-11T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 888,
#   'turnover': 203422400},
#  {'date': '2015-06-12T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1209,
#   'turnover': 281603500},
#  {'date': '2015-06-13T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1021,
#   'turnover': 236792500},
#  {'date': '2015-06-14T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 450,
#   'turnover': 106500000},
#  {'date': '2015-06-15T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3880,
#   'turnover': 928728790},
#  {'date': '2015-06-16T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 24400,
#   'turnover': 6082787410},
#  {'date': '2015-06-17T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 41237,
#   'turnover': 11036192220},
#  {'date': '2015-06-18T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 4063,
#   'turnover': 1039298000},
#  {'date': '2015-06-19T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 12526,
#   'turnover': 3164404000},
#  {'date': '2015-06-20T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 22868,
#   'turnover': 5730813610},
#  {'date': '2015-06-21T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3160,
#   'turnover': 779518700},
#  {'date': '2015-06-22T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 17630,
#   'turnover': 4438803500},
#  {'date': '2015-06-23T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 16020,
#   'turnover': 3968802200},
#  {'date': '2015-06-24T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 52755,
#   'turnover': 12898861460},
#  {'date': '2015-06-25T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 12065,
#   'turnover': 2932468700},
#  {'date': '2015-06-26T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 36894,
#   'turnover': 8949395650},
#  {'date': '2015-06-27T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 11326,
#   'turnover': 2880124000},
#  {'date': '2015-06-28T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 30650,
#   'turnover': 7853545000},
#  {'date': '2015-06-29T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 49466,
#   'turnover': 12847062370},
#  {'date': '2015-06-30T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 50489,
#   'turnover': 13601935750},
#  {'date': '2015-07-01T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 87941,
#   'turnover': 23578163800},
#  {'date': '2015-07-02T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 65610,
#   'turnover': 17656427000},
#  {'date': '2015-07-03T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 38287,
#   'turnover': 10189856100},
#  {'date': '2015-07-04T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 29239,
#   'turnover': 7718786450},
#  {'date': '2015-07-05T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 78244,
#   'turnover': 21505865930},
#  {'date': '2015-07-06T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 87682,
#   'turnover': 24605800390},
#  {'date': '2015-07-07T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 75452,
#   'turnover': 20849460000},
#  {'date': '2015-07-08T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 43404,
#   'turnover': 11971788620},
#  {'date': '2015-07-09T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 29177,
#   'turnover': 8081113350},
#  {'date': '2015-07-10T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 107775,
#   'turnover': 32058061190},
#  {'date': '2015-07-11T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 30882,
#   'turnover': 9458036500},
#  {'date': '2015-07-12T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 109768,
#   'turnover': 34517518650},
#  {'date': '2015-07-13T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 127455,
#   'turnover': 38873820660},
#  {'date': '2015-07-14T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 95197,
#   'turnover': 28599999290},
#  {'date': '2015-07-15T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 65177,
#   'turnover': 19666908060},
#  {'date': '2015-07-16T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 94914,
#   'turnover': 28086635510},
#  {'date': '2015-07-17T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 18393,
#   'turnover': 5240366230},
#  {'date': '2015-07-18T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 7451,
#   'turnover': 2134741000},
#  {'date': '2015-07-19T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3010,
#   'turnover': 858417500},
#  {'date': '2015-07-20T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 8842,
#   'turnover': 2514574320},
#  {'date': '2015-07-21T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 21149,
#   'turnover': 6094010000},
#  {'date': '2015-07-22T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 19750,
#   'turnover': 5664192500},
#  {'date': '2015-07-23T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 17459,
#   'turnover': 4983376480},
#  {'date': '2015-07-24T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 40719,
#   'turnover': 12034589860},
#  {'date': '2015-07-25T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 16715,
#   'turnover': 5066800500},
#  {'date': '2015-07-26T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 27792,
#   'turnover': 8266157460},
#  {'date': '2015-07-27T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 145639,
#   'turnover': 44540440760},
#  {'date': '2015-07-28T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 174069,
#   'turnover': 54428232740},
#  {'date': '2015-07-29T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 135789,
#   'turnover': 41518148290},
#  {'date': '2015-07-30T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 67778,
#   'turnover': 20383797230},
#  {'date': '2015-07-31T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 155700,
#   'turnover': 45536187060},
#  {'date': '2015-08-01T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 101780,
#   'turnover': 30181034900},
#  {'date': '2015-08-02T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 97761,
#   'turnover': 28880842230},
#  {'date': '2015-08-03T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 91175,
#   'turnover': 27714748900},
#  {'date': '2015-08-04T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 39364,
#   'turnover': 11898227420},
#  {'date': '2015-08-05T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 34048,
#   'turnover': 10149128760},
#  {'date': '2015-08-06T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 66066,
#   'turnover': 19509926330},
#  {'date': '2015-08-07T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 1402,
#   'turnover': 1225230000},
#  {'date': '2015-08-07T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 52789,
#   'turnover': 15350183730},
#  {'date': '2015-08-08T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 22543,
#   'turnover': 5988678000},
#  {'date': '2015-08-08T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 206030,
#   'turnover': 58797810270},
#  {'date': '2015-08-09T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 13082,
#   'turnover': 3269576000},
#  {'date': '2015-08-09T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 72516,
#   'turnover': 20063157300},
#  {'date': '2015-08-10T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 5698,
#   'turnover': 1269683000},
#  {'date': '2015-08-10T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 61811,
#   'turnover': 17421742570},
#  {'date': '2015-08-11T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 27231,
#   'turnover': 9048224000},
#  {'date': '2015-08-11T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 81002,
#   'turnover': 22835196370},
#  {'date': '2015-08-12T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 18808,
#   'turnover': 7289986000},
#  {'date': '2015-08-12T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 87199,
#   'turnover': 24613211520},
#  {'date': '2015-08-13T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 26743,
#   'turnover': 14873611000},
#  {'date': '2015-08-13T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 114594,
#   'turnover': 32063862760},
#  {'date': '2015-08-14T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 25179,
#   'turnover': 19173500000},
#  {'date': '2015-08-14T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 49037,
#   'turnover': 13620242310},
#  {'date': '2015-08-15T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 5265,
#   'turnover': 3384250000},
#  {'date': '2015-08-15T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 87267,
#   'turnover': 24513799240},
#  {'date': '2015-08-16T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 27322,
#   'turnover': 13985614000},
#  {'date': '2015-08-16T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 83144,
#   'turnover': 22686897180},
#  {'date': '2015-08-17T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 5878,
#   'turnover': 3234761000},
#  {'date': '2015-08-17T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 12623,
#   'turnover': 3449135540},
#  {'date': '2015-08-18T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 3993,
#   'turnover': 1949744000},
#  {'date': '2015-08-18T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 262212,
#   'turnover': 67023409100},
#  {'date': '2015-08-19T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 2968,
#   'turnover': 1631785000},
#  {'date': '2015-08-19T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 244168,
#   'turnover': 57580103960},
#  {'date': '2015-08-20T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 8645,
#   'turnover': 4918853000},
#  {'date': '2015-08-20T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 119390,
#   'turnover': 28674228380},
#  {'date': '2015-08-21T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 18563,
#   'turnover': 11729054000},
#  {'date': '2015-08-21T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 80653,
#   'turnover': 19278939340},
#  {'date': '2015-08-22T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 2527,
#   'turnover': 1581141000},
#  {'date': '2015-08-22T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 179508,
#   'turnover': 42155287220},
#  {'date': '2015-08-23T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 3102,
#   'turnover': 1891804000},
#  {'date': '2015-08-23T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 54942,
#   'turnover': 13202922890},
#  {'date': '2015-08-24T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 155,
#   'turnover': 95559000},
#  {'date': '2015-08-24T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 352121,
#   'turnover': 79134533840},
#  {'date': '2015-08-25T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 1786,
#   'turnover': 974088000},
#  {'date': '2015-08-25T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 665453,
#   'turnover': 145759111700},
#  {'date': '2015-08-26T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 2789,
#   'turnover': 1454403000},
#  {'date': '2015-08-26T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 152251,
#   'turnover': 35462302410},
#  {'date': '2015-08-27T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 954,
#   'turnover': 490058000},
#  {'date': '2015-08-27T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 178497,
#   'turnover': 41882815940},
#  {'date': '2015-08-28T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 5634,
#   'turnover': 2885732000},
#  {'date': '2015-08-28T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 344914,
#   'turnover': 81919940710},
#  {'date': '2015-08-29T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 703,
#   'turnover': 366949000},
#  {'date': '2015-08-29T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 96446,
#   'turnover': 23420083100},
#  {'date': '2015-08-30T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 920,
#   'turnover': 509010000},
#  {'date': '2015-08-30T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 98198,
#   'turnover': 23058242390},
#  {'date': '2015-08-31T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 396,
#   'turnover': 227296000},
#  {'date': '2015-08-31T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 135182,
#   'turnover': 32883371140},
#  {'date': '2015-09-01T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 564,
#   'turnover': 337454000},
#  {'date': '2015-09-01T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 105110,
#   'turnover': 25807241710},
#  {'date': '2015-09-02T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 105,
#   'turnover': 59149000},
#  {'date': '2015-09-02T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 105624,
#   'turnover': 25675932770},
#  {'date': '2015-09-03T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 697,
#   'turnover': 383624000},
#  {'date': '2015-09-03T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 55650,
#   'turnover': 13608835880},
#  {'date': '2015-09-04T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 2116,
#   'turnover': 1154791000},
#  {'date': '2015-09-04T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 81958,
#   'turnover': 19279241080},
#  {'date': '2015-09-05T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 412,
#   'turnover': 225681000},
#  {'date': '2015-09-05T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 105434,
#   'turnover': 26199881010},
#  {'date': '2015-09-06T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 51,
#   'turnover': 27944000},
#  {'date': '2015-09-06T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 262928,
#   'turnover': 67109804770},
#  {'date': '2015-09-07T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 505,
#   'turnover': 267625000},
#  {'date': '2015-09-07T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 58380,
#   'turnover': 14545066140},
#  {'date': '2015-09-08T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 288,
#   'turnover': 152398000},
#  {'date': '2015-09-08T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 176279,
#   'turnover': 44134184240},
#  {'date': '2015-09-09T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 20,
#   'turnover': 10300000},
#  {'date': '2015-09-09T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 207857,
#   'turnover': 51477877020},
#  {'date': '2015-09-10T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 78,
#   'turnover': 37930000},
#  {'date': '2015-09-10T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 129639,
#   'turnover': 32266276530},
#  {'date': '2015-09-11T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 10195,
#   'turnover': 4329591000},
#  {'date': '2015-09-11T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 239903,
#   'turnover': 59393189410},
#  {'date': '2015-09-12T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 5857,
#   'turnover': 2641025000},
#  {'date': '2015-09-12T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 196036,
#   'turnover': 49612547180},
#  {'date': '2015-09-13T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 7258,
#   'turnover': 2987372000},
#  {'date': '2015-09-13T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 291481,
#   'turnover': 71298006510},
#  {'date': '2015-09-14T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 1632,
#   'turnover': 645947000},
#  {'date': '2015-09-14T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 316787,
#   'turnover': 75807691890},
#  {'date': '2015-09-15T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 1067,
#   'turnover': 435801000},
#  {'date': '2015-09-15T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 241252,
#   'turnover': 57704444830},
#  {'date': '2015-09-16T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 747,
#   'turnover': 305864000},
#  {'date': '2015-09-16T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 548023,
#   'turnover': 129231922820},
#  {'date': '2015-09-17T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 3004,
#   'turnover': 1154273000},
#  {'date': '2015-09-17T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 291685,
#   'turnover': 70577746300},
#  {'date': '2015-09-18T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 16121,
#   'turnover': 6094910000},
#  {'date': '2015-09-18T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 338003,
#   'turnover': 81241546960},
#  {'date': '2015-09-19T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 2800,
#   'turnover': 1059450000},
#  {'date': '2015-09-19T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 157843,
#   'turnover': 37547701280},
#  {'date': '2015-09-20T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 1919,
#   'turnover': 753215000},
#  {'date': '2015-09-20T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 82222,
#   'turnover': 19399276610},
#  {'date': '2015-09-21T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 7795,
#   'turnover': 3089905000},
#  {'date': '2015-09-21T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 533465,
#   'turnover': 126111656160},
#  {'date': '2015-09-22T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 3491,
#   'turnover': 1341464000},
#  {'date': '2015-09-22T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 466137,
#   'turnover': 112344392770},
#  {'date': '2015-09-23T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 1061,
#   'turnover': 407382000},
#  {'date': '2015-09-23T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 361527,
#   'turnover': 86354801940},
#  {'date': '2015-09-24T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 16350,
#   'turnover': 5935260000},
#  {'date': '2015-09-24T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 396984,
#   'turnover': 96132860870},
#  {'date': '2015-09-25T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 32412,
#   'turnover': 10593554000},
#  {'date': '2015-09-25T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 830152,
#   'turnover': 199651198400},
#  {'date': '2015-09-26T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 2141,
#   'turnover': 683242000},
#  {'date': '2015-09-26T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 608406,
#   'turnover': 145848711740},
#  {'date': '2015-09-27T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 5565,
#   'turnover': 1733659000},
#  {'date': '2015-09-27T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 295825,
#   'turnover': 70574279170},
#  {'date': '2015-09-28T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 13074,
#   'turnover': 3581474000},
#  {'date': '2015-09-28T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 848750,
#   'turnover': 210917023370},
#  {'date': '2015-09-29T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 11402,
#   'turnover': 3095709000},
#  {'date': '2015-09-29T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 771634,
#   'turnover': 187227755710},
#  {'date': '2015-09-30T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 6341,
#   'turnover': 1890142000},
#  {'date': '2015-09-30T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 389241,
#   'turnover': 94833096560},
#  {'date': '2015-10-01T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 4656,
#   'turnover': 1315599000},
#  {'date': '2015-10-01T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 295192,
#   'turnover': 70990867910},
#  {'date': '2015-10-02T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 14673,
#   'turnover': 4074452000},
#  {'date': '2015-10-02T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 279384,
#   'turnover': 67449249620},
#  {'date': '2015-10-03T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 2528,
#   'turnover': 707870000},
#  {'date': '2015-10-03T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 176752,
#   'turnover': 42575618170},
#  {'date': '2015-10-04T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 3,
#   'turnover': 840000},
#  {'date': '2015-10-04T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 237188,
#   'turnover': 57456759900},
#  {'date': '2015-10-05T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
# ...
#  {'date': '2016-06-12T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 64256,
#   'turnover': 147221251000},
#  {'date': '2016-06-12T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 11301004,
#   'turnover': 1833964054914},
#  {'date': '2016-06-13T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 109538,
#   'turnover': 271320599000},
#  {'date': '2016-06-13T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 10169920,
#   'turnover': 1522169098388},
#  {'date': '2016-06-14T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 63116,
#   'turnover': 171829095000},
#  {'date': '2016-06-14T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 7037071,
#   'turnover': 1075835170061},
#  {'date': '2016-06-15T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 7822,
#   'turnover': 21724002000},
#  {'date': '2016-06-15T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 4088716,
#   'turnover': 631779922376},
#  {'date': '2016-06-16T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 21467,
#   'turnover': 58201047000},
#  {'date': '2016-06-16T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 10466098,
#   'turnover': 1595928336863},
#  {'date': '2016-06-17T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 238594,
#   'turnover': 545245808000},
#  {'date': '2016-06-17T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 9360277,
#   'turnover': 1342305133224},
#  {'date': '2016-06-18T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 87889,
#   'turnover': 140557387000},
#  {'date': '2016-06-18T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 8940775,
#   'turnover': 1221196488569},
#  {'date': '2016-06-19T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 31967,
#   'turnover': 51375022000},
#  {'date': '2016-06-19T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 5398913,
#   'turnover': 725441258861},
#  {'date': '2016-06-20T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 85376,
#   'turnover': 129425363000},
#  {'date': '2016-06-20T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 7251466,
#   'turnover': 1003993009355},
#  {'date': '2016-06-21T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 110058,
#   'turnover': 192397485000},
#  {'date': '2016-06-21T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 14881384,
#   'turnover': 2282344937910},
#  {'date': '2016-06-22T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 80571,
#   'turnover': 177053688000},
#  {'date': '2016-06-22T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 8982049,
#   'turnover': 1441164648174},
#  {'date': '2016-06-23T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 18147,
#   'turnover': 39914253000},
#  {'date': '2016-06-23T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 14214748,
#   'turnover': 2530021776863},
#  {'date': '2016-06-24T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 13780,
#   'turnover': 28835559000},
#  {'date': '2016-06-24T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 9269306,
#   'turnover': 1511528001870},
#  {'date': '2016-06-25T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 9319,
#   'turnover': 19808217000},
#  {'date': '2016-06-25T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 7919508,
#   'turnover': 1196720947724},
#  {'date': '2016-06-26T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 20479,
#   'turnover': 44846611000},
#  {'date': '2016-06-26T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 6575441,
#   'turnover': 1039720725968},
#  {'date': '2016-06-27T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 9445,
#   'turnover': 20466057000},
#  {'date': '2016-06-27T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 6750680,
#   'turnover': 1056549032089},
#  {'date': '2016-06-28T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 44443,
#   'turnover': 85617651000},
#  {'date': '2016-06-28T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 4350480,
#   'turnover': 674503265486},
#  {'date': '2016-06-29T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 45597,
#   'turnover': 87738100000},
#  {'date': '2016-06-29T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 4200957,
#   'turnover': 662519317720},
#  {'date': '2016-06-30T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 44336,
#   'turnover': 84233383000},
#  {'date': '2016-06-30T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 6094399,
#   'turnover': 923881049451},
#  {'date': '2016-07-01T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 29116,
#   'turnover': 52399464000},
#  {'date': '2016-07-01T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 4942081,
#   'turnover': 731179771678},
#  {'date': '2016-07-02T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 10559,
#   'turnover': 18402733000},
#  {'date': '2016-07-02T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 5208996,
#   'turnover': 757772122046},
#  {'date': '2016-07-03T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 13947,
#   'turnover': 24731673000},
#  {'date': '2016-07-03T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 8578083,
#   'turnover': 1282153736924},
#  {'date': '2016-07-04T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 14528,
#   'turnover': 24797037000},
#  {'date': '2016-07-04T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3861275,
#   'turnover': 579165399318},
#  {'date': '2016-07-05T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 82819,
#   'turnover': 125664355000},
#  {'date': '2016-07-05T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3437190,
#   'turnover': 513621794425},
#  {'date': '2016-07-06T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 51148,
#   'turnover': 80867590000},
#  {'date': '2016-07-06T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2413224,
#   'turnover': 359719061759},
#  {'date': '2016-07-07T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 17865,
#   'turnover': 27583430000},
#  {'date': '2016-07-07T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 9367791,
#   'turnover': 1492484351211},
#  {'date': '2016-07-08T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 30966,
#   'turnover': 51507193000},
#  {'date': '2016-07-08T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 4519897,
#   'turnover': 705020025416},
#  {'date': '2016-07-09T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 23017,
#   'turnover': 39242153000},
#  {'date': '2016-07-09T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 6311633,
#   'turnover': 997683400672},
#  {'date': '2016-07-10T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 26907,
#   'turnover': 45433031000},
#  {'date': '2016-07-10T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3044980,
#   'turnover': 471685786088},
#  {'date': '2016-07-11T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 31476,
#   'turnover': 50721564000},
#  {'date': '2016-07-11T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3629143,
#   'turnover': 559248031006},
#  {'date': '2016-07-12T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 17155,
#   'turnover': 27431897000},
#  {'date': '2016-07-12T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 4205111,
#   'turnover': 641701822152},
#  {'date': '2016-07-13T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 9966,
#   'turnover': 15810095000},
#  {'date': '2016-07-13T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1889208,
#   'turnover': 287212735500},
#  {'date': '2016-07-14T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 35096,
#   'turnover': 59234265000},
#  {'date': '2016-07-14T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2503101,
#   'turnover': 382023283284},
#  {'date': '2016-07-15T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 72230,
#   'turnover': 131357838000},
#  {'date': '2016-07-15T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1993004,
#   'turnover': 303853468676},
#  {'date': '2016-07-16T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 24788,
#   'turnover': 44126541000},
#  {'date': '2016-07-16T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1507013,
#   'turnover': 233479169403},
#  {'date': '2016-07-17T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 44240,
#   'turnover': 73841240000},
#  {'date': '2016-07-17T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3534223,
#   'turnover': 542644151848},
#  {'date': '2016-07-18T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 31017,
#   'turnover': 52159372000},
#  {'date': '2016-07-18T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3428931,
#   'turnover': 513574401948},
#  {'date': '2016-07-19T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 81365,
#   'turnover': 141707566000},
#  {'date': '2016-07-19T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1389304,
#   'turnover': 210142726731},
#  {'date': '2016-07-20T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 138633,
#   'turnover': 253917583000},
#  {'date': '2016-07-20T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1897157,
#   'turnover': 295809437576},
#  {'date': '2016-07-21T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 89828,
#   'turnover': 167066751000},
#  {'date': '2016-07-21T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1440875,
#   'turnover': 220247591717},
#  {'date': '2016-07-22T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 177839,
#   'turnover': 375077357000},
#  {'date': '2016-07-22T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3357907,
#   'turnover': 523183409264},
#  {'date': '2016-07-23T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 104055,
#   'turnover': 230245261000},
#  {'date': '2016-07-23T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1285182,
#   'turnover': 196737539077},
#  {'date': '2016-07-24T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 241881,
#   'turnover': 487437544000},
#  {'date': '2016-07-24T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 645713,
#   'turnover': 100201484663},
#  {'date': '2016-07-25T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 53905,
#   'turnover': 110265520000},
#  {'date': '2016-07-25T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 787204,
#   'turnover': 121626190616},
#  {'date': '2016-07-26T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 196762,
#   'turnover': 372868747000},
#  {'date': '2016-07-26T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1901241,
#   'turnover': 296007190671},
#  {'date': '2016-07-27T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 97522,
#   'turnover': 189829809000},
#  {'date': '2016-07-27T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1913622,
#   'turnover': 301880222360},
#  {'date': '2016-07-28T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 15396,
#   'turnover': 30030789000},
#  {'date': '2016-07-28T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 912306,
#   'turnover': 140172007615},
#  {'date': '2016-07-29T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 12824,
#   'turnover': 24807846000},
#  {'date': '2016-07-29T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 742147,
#   'turnover': 113305708495},
#  {'date': '2016-07-30T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 3716,
#   'turnover': 7127257000},
#  {'date': '2016-07-30T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 551918,
#   'turnover': 84319956096},
#  {'date': '2016-07-31T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 25706,
#   'turnover': 48368129000},
#  {'date': '2016-07-31T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 4300893,
#   'turnover': 692474739718},
#  {'date': '2016-08-01T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 28717,
#   'turnover': 53022719000},
#  {'date': '2016-08-01T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2708637,
#   'turnover': 449662706837},
#  {'date': '2016-08-02T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 135371,
#   'turnover': 214918988000},
#  {'date': '2016-08-02T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 11577585,
#   'turnover': 2100282986459},
#  {'date': '2016-08-03T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 78664,
#   'turnover': 135476643000},
#  {'date': '2016-08-03T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 6901209,
#   'turnover': 1272479008536},
#  {'date': '2016-08-04T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 63941,
#   'turnover': 120630451000},
#  {'date': '2016-08-04T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 4332703,
#   'turnover': 768597411017},
#  {'date': '2016-08-05T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 33882,
#   'turnover': 64573769000},
#  {'date': '2016-08-05T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2049778,
#   'turnover': 363417240286},
#  {'date': '2016-08-06T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 66266,
#   'turnover': 121464231000},
#  {'date': '2016-08-06T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 4401864,
#   'turnover': 775545496567},
#  {'date': '2016-08-07T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 23677,
#   'turnover': 43861882000},
#  {'date': '2016-08-07T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2929732,
#   'turnover': 501039107131},
#  {'date': '2016-08-08T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 33750,
#   'turnover': 63557525000},
#  {'date': '2016-08-08T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2138587,
#   'turnover': 364128027228},
#  {'date': '2016-08-09T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 80542,
#   'turnover': 165035687000},
#  {'date': '2016-08-09T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2696464,
#   'turnover': 468434765586},
#  {'date': '2016-08-10T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 32957,
#   'turnover': 68102570000},
#  {'date': '2016-08-10T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2696328,
#   'turnover': 481363877235},
#  {'date': '2016-08-11T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 15688,
#   'turnover': 31302287000},
#  {'date': '2016-08-11T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1464877,
#   'turnover': 248906064471},
#  ...]

# %% [markdown]
# ## 1. Download historical data

# %%
now = datetime.now().isoformat()
bitmex_params = [('funding',{'symbol':'XBTUSD','count':'100','reverse':'false','start':'0','endTime':now}),    # funding_rate
                 #('stats/history',{}),    # volume
                 #('stats',{}),    # openInterest, openValue "rootSymbol" -- call "XBT" and "ETH"
                ]

# Initialise historical data. This will not overwrite files of the same name in the target folder so be sure to delete them first if they exist.
def get_historical_bitmex(bitmex_params):
    sample = 'sample'
    for item in bitmex_params:
        endpoint, params_dict = item
        filepath = 'data/Bitmex/' + endpoint.replace('/', '_') + '.csv'
        
        if os.path.isfile(filepath):
            print('Please delete or rename previous file of same name.')
            raise
        
        while sample!='':
            api_call_url = 'https://www.bitmex.com/api/v1/' + endpoint + '?_format=csv'
            # Check if any parameters are applied
            if bool(params_dict):
                for param in params_dict:
                    api_call_url += '&' + param + '=' + params_dict[param] 
            r = requests.get(api_call_url)
            if r.status_code != 200:
                print(r.status_code)
                return
            csv_list = r.text.split('\n')
            
            # Create a new file only if one does not exist, and append the headers
            if not os.path.isfile(filepath):
                with open(filepath, 'w') as csv_file:
                    for row in csv_list[0]:
                        csv_file.write(row)
            
            with open(filepath, 'a') as csv_file:
                # Append the data, but skip the headers
                for row in csv_list[1:]:
                    csv_file.write('\n'+row)
            
            if bool(params_dict):
                params_dict['start'] = str(int(params_dict['start']) + int(params_dict['count']))
                sample = r.text[:5]
            else:
                sample = ''

# %%
get_historical_bitmex(bitmex_params)

# %% [markdown]
# ## 2. Update data

# %%
# Ref: https://www.bitmex.com/api/explorer/
# Parameters for each API call. All variables must be in string format
bitmex_params = [('funding',{'symbol':'XBTUSD','count':'100','reverse':'false','start':'0'}),
                 #('liquidation',{}),
                 #('stats/history',{}),
                ]

def update_bitmex(bitmex_params):
    # Update data from timestamp of last entry in file
    for item in bitmex_params:
        endpoint, params_dict = item
        filepath = 'data/Bitmex/' + endpoint + '.csv'
        api_call_url = 'https://www.bitmex.com/api/v1/' + endpoint + '?_format=csv'
        
        # Check if any parameters are applied
        if bool(params_dict):
            # Check for timestamp of last entry
            if endpoint == 'funding':
                timestamp_df = pd.read_csv(filepath, usecols=['timestamp'])
            elif endpoint == 'stats/history':
                timestamp_df = pd.read_csv(filepath, usecols=['date'])
            elif endpoint == 'stats':
                timestamp_df = pd.read_csv(filepath, usecols=['timestamp'])

            params_dict['startTime'] = timestamp_df.values[-1][0]
            params_dict['start'] = '1'
            
            for param in params_dict:
                api_call_url += '&' + param + '=' + params_dict[param] 

        r = requests.get(api_call_url)
        if r.status_code != 200:
            print(r.status_code)
            break
        
        csv_list = r.text.split('\n')
        with open(filepath, 'a') as csv_file:
            # Append the data, but skip the headers
            for row in csv_list[1:]:
                csv_file.write(row + '\n')
                
update_bitmex(bitmex_params)

# %% [markdown]
# ### Stats

# %%
r = requests.get('https://www.bitmex.com/api/v1/stats')
if r.status_code != 200:
    print(r.status_code)

data = r.json()
filtered_data = [data[i] for i in range(len(data)) if (data[i]['rootSymbol']=='XBT') | (data[i]['rootSymbol']=='ETH')]

stats_df = pd.DataFrame(filtered_data)
stats_df['Time'] = datetime.now()
stats_df.to_csv('data/Bitmex/stats.csv', mode='a', header=False, index=False)

# %% [markdown]
# ### Stats history

# %%
r = requests.get('https://www.bitmex.com/api/v1/stats/history')
if r.status_code != 200:
    print(r.status_code)

data = r.json()
filtered_data = [data[i] for i in range(len(data)) if (data[i]['rootSymbol']=='XBT') | (data[i]['rootSymbol']=='ETH')]

stats_hist_df = pd.DataFrame(filtered_data)
stats_hist_df.to_csv('data/Bitmex/stats_history.csv', mode='w', index=False)

# %% [markdown]
# # Coinmetrics
# https://docs.coinmetrics.io/api/v2/

# %% [markdown]
# ## a) Get historical data

# %%
# Get full data
metrics = 'AdrActCnt,BlkCnt,BlkSizeByte,BlkSizeMeanByte,CapMVRVCur,CapMrktCurUSD,CapRealUSD,DiffMean,FeeMeanNtv,FeeMeanUSD,FeeMedNtv,FeeMedUSD,FeeTotNtv,FeeTotUSD,IssContNtv,IssContPctAnn,IssContUSD,IssTotNtv,IssTotUSD,NVTAdj,NVTAdj90,PriceBTC,PriceUSD,ROI1yr,ROI30d,SplyCur,TxCnt,TxTfrCnt,TxTfrValAdjNtv,TxTfrValAdjUSD,TxTfrValMeanNtv,TxTfrValMeanUSD,TxTfrValMedNtv,TxTfrValMedUSD,TxTfrValNtv,TxTfrValUSD,VtyDayRet180d,VtyDayRet30d,VtyDayRet60d'
r = requests.get('https://community-api.coinmetrics.io/v2/assets/btc/metricdata.csv?metrics='+ metrics)
if r.status_code != 200:
    print(r.status_code)
    raise

# %%
csv_list = r.text.split('\n')
with open('data/Coinmetrics/Coinmetrics_btc.csv', 'w') as csv_file:
    for row in csv_list:
        csv_file.write(row)

# %% [markdown]
# ## b) Update daily

# %%
# Get timestamp of last entry
filepath = 'data/Coinmetrics/Coinmetrics_btc.csv'
timestamp_df = pd.read_csv(filepath, usecols=['time'])
timestamp_df = timestamp_df.astype('datetime64')
start_time = str(timestamp_df.values[-1][0]+10000000)
start = '&start=' + str(start_time)[:23] + 'Z'

metrics = 'AdrActCnt,BlkCnt,BlkSizeByte,BlkSizeMeanByte,CapMVRVCur,CapMrktCurUSD,CapRealUSD,DiffMean,FeeMeanNtv,FeeMeanUSD,FeeMedNtv,FeeMedUSD,FeeTotNtv,FeeTotUSD,IssContNtv,IssContPctAnn,IssContUSD,IssTotNtv,IssTotUSD,NVTAdj,NVTAdj90,PriceBTC,PriceUSD,ROI1yr,ROI30d,SplyCur,TxCnt,TxTfrCnt,TxTfrValAdjNtv,TxTfrValAdjUSD,TxTfrValMeanNtv,TxTfrValMeanUSD,TxTfrValMedNtv,TxTfrValMedUSD,TxTfrValNtv,TxTfrValUSD,VtyDayRet180d,VtyDayRet30d,VtyDayRet60d' #,TxTfr
r = requests.get('https://community-api.coinmetrics.io/v2/assets/btc/metricdata.csv?metrics='+ metrics + start)
if r.status_code != 200:
    print(r.status_code)
    raise
csv_list = r.text.split('\n')
with open(filepath, 'a') as csv_file:
    for row in csv_list[1:]:
        csv_file.write(row)

# %% [markdown]
# # Quandl
# https://www.quandl.com/tools/python

# %%
import quandl

# %% [markdown]
# ## Get historical data

# %%
for code in ["BCHAIN/MIREV","BCHAIN/DIFF","BCHAIN/HRATE","BCHAIN/TOTBC","BCHAIN/TOUTV"]:
    data_df = quandl.get(code)
    data_df.to_csv('data/Quandl/'+ code.replace('/','_')+'.csv')
# Out:
# Error : Connection is already closed.
# error from callback <bound method BitMEXWebsocket.__on_error of <bitmex_websocket.BitMEXWebsocket object at 0x000002183B20BF98>>: Connection is already closed.
# Error : Connection is already closed.
# error from callback <bound method BitMEXWebsocket.__on_error of <bitmex_websocket.BitMEXWebsocket object at 0x000002183C03DF28>>: Connection is already closed.

# %% [markdown]
# ## Update data

# %%
for code in ["BCHAIN/MIREV","BCHAIN/DIFF","BCHAIN/HRATE","BCHAIN/TOTBC","BCHAIN/TOUTV"]:
    old_data_df = pd.read_csv('data/Quandl/'+ code.replace('/','_') + '.csv', usecols=['Date'])
    final_timestamp = old_data_df.astype('datetime64').values[-1] + pd.Timedelta(1, unit='d')
    start = str(final_timestamp[0])[:10]
    data_df = quandl.get(code, start_date=start)
    # Append    
    data_df.to_csv('data/Quandl/'+ code.replace('/','_') + '.csv', mode='a', header=False)
# Out:
# ---------------------------------------------------------------------------
# LimitExceededError                        Traceback (most recent call last)
# <ipython-input-5-f65ae6c5ac36> in <module>
#       3     final_timestamp = old_data_df.astype('datetime64').values[-1] + pd.Timedelta(1, unit='d')
#       4     start = str(final_timestamp[0])[:10]
# ----> 5     data_df = quandl.get(code, start_date=start)
#       6     # Append
#       7     data_df.to_csv('data/Quandl/'+ code.replace('/','_'), mode='a', header=False)
#
# ~\Miniconda3\envs\venture_256\lib\site-packages\quandl\get.py in get(dataset, **kwargs)
#      46         if dataset_args['column_index'] is not None:
#      47             kwargs.update({'column_index': dataset_args['column_index']})
# ---> 48         data = Dataset(dataset_args['code']).data(params=kwargs, handle_column_not_found=True)
#      49     # Array
#      50     elif isinstance(dataset, list):
#
# ~\Miniconda3\envs\venture_256\lib\site-packages\quandl\model\dataset.py in data(self, **options)
#      45         updated_options = Util.merge_options('params', params, **options)
#      46         try:
# ---> 47             return Data.all(**updated_options)
#      48         except NotFoundError:
#      49             if handle_not_found_error:
#
# ~\Miniconda3\envs\venture_256\lib\site-packages\quandl\operations\list.py in all(cls, **options)
#      13             options['params'] = {}
#      14         path = Util.constructed_path(cls.list_path(), options['params'])
# ---> 15         r = Connection.request('get', path, **options)
#      16         response_data = r.json()
#      17         Util.convert_to_dates(response_data)
#
# ~\Miniconda3\envs\venture_256\lib\site-packages\quandl\connection.py in request(cls, http_verb, url, **options)
#      36         abs_url = '%s/%s' % (ApiConfig.api_base, url)
#      37
# ---> 38         return cls.execute_request(http_verb, abs_url, **options)
#      39
#      40     @classmethod
#
# ~\Miniconda3\envs\venture_256\lib\site-packages\quandl\connection.py in execute_request(cls, http_verb, url, **options)
#      48                                        **options)
#      49             if response.status_code < 200 or response.status_code >= 300:
# ---> 50                 cls.handle_api_error(response)
#      51             else:
#      52                 return response
#
# ~\Miniconda3\envs\venture_256\lib\site-packages\quandl\connection.py in handle_api_error(cls, resp)
#     112         klass = d_klass.get(code_letter, QuandlError)
#     113
# --> 114         raise klass(message, resp.status_code, resp.text, resp.headers, code)
#
# LimitExceededError: (Status 429) (Quandl Error QELx01) You have exceeded the anonymous user limit of 50 calls per day. To make more calls today, please register for a free Quandl account and then include your API key with your requests.

# %% [markdown]
# # Glassnode

# %% [markdown]
# ## Get historical

# %%
variables = ['sopr', 'sopr_adjusted', 'cdd', 'average_dormancy', 'average_dormancy_supply_adjusted']
for var in variables:
    r = requests.get('https://api.glassnode.com/v1/metrics/indicators/'+ var + '?a=btc&api_key=022517a3-d79c-4510-9063-8d83780bb927')
    r.raise_for_status()
    json_file = r.json()
    glassnode_df = pd.DataFrame(json_file)
    glassnode_df['Time'] = pd.to_datetime(glassnode_df['t'], unit='s')
    glassnode_df.to_csv('data/Glassnode/' + var + '.csv', index=False)

# %% [markdown]
# ## Update Data

# %%
variables = ['sopr', 'sopr_adjusted', 'cdd', 'average_dormancy', 'average_dormancy_supply_adjusted']
for var in variables:
    old_data_df = pd.read_csv('data/Glassnode/' + var + '.csv', usecols=['t'])
    final_timestamp = old_data_df.values[-1][0]
    # Filter from the time of 1 hour from last timestamp
    r = requests.get('https://api.glassnode.com/v1/metrics/indicators/'+ var + '?a=btc&s='+ str(final_timestamp+86400) + '&api_key=022517a3-d79c-4510-9063-8d83780bb927')
    r.raise_for_status()
    json_file = r.json()
    if json_file:
        new_timestamp = json_file[0]['t']
        glassnode_df = pd.DataFrame(json_file)
        glassnode_df['Time'] = pd.to_datetime(glassnode_df['t'], unit='s')
        glassnode_df.to_csv('data/Glassnode/' + var + '.csv', mode='a', header=False, index=False)

# %% [markdown]
# # Upload to S3

# %%
def upload_file(file_name, bucket, object_name=None):
    """Upload a file to an S3 bucket

    :param file_name: File to upload
    :param bucket: Bucket to upload to
    :param object_name: S3 object name. If not specified then file_name is used
    :return: True if file was uploaded, else False
    """

    # If S3 object_name was not specified, use file_name
    if object_name is None:
        object_name = file_name

    # Upload the file
    s3_client = boto3.client('s3')
    try:
        response = s3_client.upload_file(file_name, bucket, object_name)
    except ClientError as e:
        logging.error(e)
        return False
    return True

# %%
# Let's use Amazon S3
s3 = boto3.resource('s3')
# Print out bucket names
for bucket in s3.buckets.all():
    print(bucket.name)
# Out:
# your-s3-bucket-name-deeloon

# %%
data = open('data.json', 'rb')
s3.Bucket('your-s3-bucket-name-deeloon').put_object(Key='data.json', Body=data)
# Out:
# s3.Object(bucket_name='your-s3-bucket-name-deeloon', key='data.json')
