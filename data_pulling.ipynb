# %%
import requests
import json
import csv
import os
import datetime
import pandas as pd
import logging
import boto3
from botocore.exceptions import ClientError

# %% [markdown]
# # Bitmex
# https://www.bitmex.com/api/explorer/#/
#
# use XBTUSD as currency

# %%
r = requests.get('https://www.bitmex.com/api/v1/stats/history?')
if r.status_code != 200:
    print(r.status_code)
r.json()
# Out:
# [{'date': '2014-11-22T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2,
#   'turnover': 0},
#  {'date': '2014-11-22T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 0},
#  {'date': '2014-11-23T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2,
#   'turnover': 0},
#  {'date': '2014-11-23T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 0},
#  {'date': '2014-11-24T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 30315,
#   'turnover': 0},
#  {'date': '2014-11-24T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 0},
#  {'date': '2014-11-25T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 49220,
#   'turnover': 0},
#  {'date': '2014-11-25T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 0},
#  {'date': '2014-11-26T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 29212,
#   'turnover': 0},
#  {'date': '2014-11-26T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 0},
#  {'date': '2014-11-27T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 282,
#   'turnover': 0},
#  {'date': '2014-11-27T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 0},
#  {'date': '2014-11-28T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 5927,
#   'turnover': 0},
#  {'date': '2014-11-28T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 0},
#  {'date': '2014-11-29T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3142,
#   'turnover': 39269000},
#  {'date': '2014-11-29T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 39269000},
#  {'date': '2014-11-30T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1493,
#   'turnover': 0},
#  {'date': '2014-11-30T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 0},
#  {'date': '2014-12-01T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 5397,
#   'turnover': 466500450},
#  {'date': '2014-12-01T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 466500450},
#  {'date': '2014-12-02T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 10805,
#   'turnover': 1102611100},
#  {'date': '2014-12-02T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 1102611100},
#  {'date': '2014-12-03T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 9478,
#   'turnover': 3019217000},
#  {'date': '2014-12-03T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 3019217000},
#  {'date': '2014-12-04T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 41430,
#   'turnover': 9798877800},
#  {'date': '2014-12-04T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 9798877800},
#  {'date': '2014-12-05T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 39435,
#   'turnover': 5170555000},
#  {'date': '2014-12-05T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 5170555000},
#  {'date': '2014-12-06T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2059,
#   'turnover': 67044660},
#  {'date': '2014-12-06T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 67044660},
#  {'date': '2014-12-07T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 704,
#   'turnover': 78850000},
#  {'date': '2014-12-07T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 78850000},
#  {'date': '2014-12-08T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 46759,
#   'turnover': 14877800450},
#  {'date': '2014-12-08T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 1,
#   'turnover': 0},
#  {'date': '2014-12-08T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 14877800450},
#  {'date': '2014-12-09T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 85277,
#   'turnover': 17879326190},
#  {'date': '2014-12-09T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 57,
#   'turnover': 792354616},
#  {'date': '2014-12-09T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 18671680806},
#  {'date': '2014-12-10T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 9302,
#   'turnover': 1862936000},
#  {'date': '2014-12-10T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 3,
#   'turnover': 0},
#  {'date': '2014-12-10T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 1862936000},
#  {'date': '2014-12-11T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 11161,
#   'turnover': 421993670},
#  {'date': '2014-12-11T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 32,
#   'turnover': 248394061},
#  {'date': '2014-12-11T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 670387731},
#  {'date': '2014-12-12T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 52586,
#   'turnover': 1453236170},
#  {'date': '2014-12-12T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 385,
#   'turnover': 9932050503},
#  {'date': '2014-12-12T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 11385286673},
#  {'date': '2014-12-13T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 4391,
#   'turnover': 355985740},
#  {'date': '2014-12-13T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 18,
#   'turnover': 427256530},
#  {'date': '2014-12-13T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 783242270},
#  {'date': '2014-12-14T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2350,
#   'turnover': 330342290},
#  {'date': '2014-12-14T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 28,
#   'turnover': 540540540},
#  {'date': '2014-12-14T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 870882830},
#  {'date': '2014-12-15T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 35092,
#   'turnover': 3162782260},
#  {'date': '2014-12-15T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 49,
#   'turnover': 1024614589},
#  {'date': '2014-12-15T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 4187396849},
#  {'date': '2014-12-16T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 61020,
#   'turnover': 18725170060},
#  {'date': '2014-12-16T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 279,
#   'turnover': 6922915118},
#  {'date': '2014-12-16T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 25648085178},
#  {'date': '2014-12-17T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 80407,
#   'turnover': 9883974260},
#  {'date': '2014-12-17T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 118,
#   'turnover': 3162906867},
#  {'date': '2014-12-17T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 13046881127},
#  {'date': '2014-12-18T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 67001,
#   'turnover': 9434302610},
#  {'date': '2014-12-18T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 144,
#   'turnover': 1025245594},
#  {'date': '2014-12-18T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 10459548204},
#  {'date': '2014-12-19T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 6740,
#   'turnover': 363064420},
#  {'date': '2014-12-19T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 28,
#   'turnover': 669523262},
#  {'date': '2014-12-19T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 1032587682},
#  {'date': '2014-12-20T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 14965,
#   'turnover': 3686660510},
#  {'date': '2014-12-20T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 41,
#   'turnover': 546076335},
#  {'date': '2014-12-20T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 4232736845},
#  {'date': '2014-12-21T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 9027,
#   'turnover': 2362598790},
#  {'date': '2014-12-21T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 2,
#   'turnover': 58707840},
#  {'date': '2014-12-21T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 2421306630},
#  {'date': '2014-12-22T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 21545,
#   'turnover': 3133576890},
#  {'date': '2014-12-22T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 51,
#   'turnover': 710735712},
#  {'date': '2014-12-22T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 3844312602},
#  {'date': '2014-12-23T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 11478,
#   'turnover': 3551378820},
#  {'date': '2014-12-23T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 110,
#   'turnover': 3025291718},
#  {'date': '2014-12-23T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 6576670538},
#  {'date': '2014-12-24T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 4989,
#   'turnover': 1064900000},
#  {'date': '2014-12-24T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 57,
#   'turnover': 1560933779},
#  {'date': '2014-12-24T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 2625833779},
#  {'date': '2014-12-25T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 5770,
#   'turnover': 759072000},
#  {'date': '2014-12-25T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2014-12-25T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 759072000},
#  {'date': '2014-12-26T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 26946,
#   'turnover': 318783040},
#  {'date': '2014-12-26T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 102,
#   'turnover': 248101971},
#  {'date': '2014-12-26T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 566885011},
#  {'date': '2014-12-27T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 25617,
#   'turnover': 6613332950},
#  {'date': '2014-12-27T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 31,
#   'turnover': 894419525},
#  {'date': '2014-12-27T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 7507752475},
#  {'date': '2014-12-28T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3529,
#   'turnover': 348264390},
#  {'date': '2014-12-28T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 33,
#   'turnover': 972193483},
#  {'date': '2014-12-28T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 1320457873},
#  {'date': '2014-12-29T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3799,
#   'turnover': 82037910},
#  {'date': '2014-12-29T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 12,
#   'turnover': 362592922},
#  {'date': '2014-12-29T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 444630832},
#  {'date': '2014-12-30T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 17137,
#   'turnover': 5092152360},
#  {'date': '2014-12-30T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 163,
#   'turnover': 4958837632},
#  {'date': '2014-12-30T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 10050989992},
#  {'date': '2014-12-31T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 4153,
#   'turnover': 695976500},
#  {'date': '2014-12-31T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 8,
#   'turnover': 233617518},
#  {'date': '2014-12-31T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 929594018},
#  {'date': '2015-01-01T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 5887,
#   'turnover': 496180460},
#  {'date': '2015-01-01T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 22,
#   'turnover': 658719026},
#  {'date': '2015-01-01T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 1154899486},
#  {'date': '2015-01-02T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 7158,
#   'turnover': 560072240},
#  {'date': '2015-01-02T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 12,
#   'turnover': 357960834},
#  {'date': '2015-01-02T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 918033074},
#  {'date': '2015-01-03T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 18854,
#   'turnover': 2139426600},
#  {'date': '2015-01-03T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 193,
#   'turnover': 6030578979},
#  {'date': '2015-01-03T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 8170005579},
#  {'date': '2015-01-04T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 127162,
#   'turnover': 31109261780},
#  {'date': '2015-01-04T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 140,
#   'turnover': 4708904475},
#  {'date': '2015-01-04T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 35818166255},
#  {'date': '2015-01-05T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 15,
#   'turnover': 750000000},
#  {'date': '2015-01-05T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 75387,
#   'turnover': 16615677270},
#  {'date': '2015-01-05T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 244,
#   'turnover': 8262635540},
#  {'date': '2015-01-05T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 25628312810},
#  {'date': '2015-01-06T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 11,
#   'turnover': 566750000},
#  {'date': '2015-01-06T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 88826,
#   'turnover': 27193916610},
#  {'date': '2015-01-06T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 83,
#   'turnover': 2833098424},
#  {'date': '2015-01-06T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 30593765034},
#  {'date': '2015-01-07T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 17,
#   'turnover': 921250000},
#  {'date': '2015-01-07T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 57771,
#   'turnover': 17992437800},
#  {'date': '2015-01-07T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 506,
#   'turnover': 16467990694},
#  {'date': '2015-01-07T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 35381678494},
#  {'date': '2015-01-08T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 2,
#   'turnover': 120000000},
#  {'date': '2015-01-08T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 36372,
#   'turnover': 11444923940},
#  {'date': '2015-01-08T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 154,
#   'turnover': 4927277468},
#  {'date': '2015-01-08T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 16492201408},
#  {'date': '2015-01-09T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 1,
#   'turnover': 60000000},
#  {'date': '2015-01-09T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 28658,
#   'turnover': 8749755810},
#  {'date': '2015-01-09T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 37,
#   'turnover': 1221117425},
#  {'date': '2015-01-09T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 10030873235},
#  {'date': '2015-01-10T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-01-10T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 16709,
#   'turnover': 4995821950},
#  {'date': '2015-01-10T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 30,
#   'turnover': 999663114},
#  {'date': '2015-01-10T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 5995485064},
#  {'date': '2015-01-11T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-01-11T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 8435,
#   'turnover': 2395389190},
#  {'date': '2015-01-11T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 5,
#   'turnover': 178557451},
#  {'date': '2015-01-11T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 2573946641},
#  {'date': '2015-01-12T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-01-12T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 27925,
#   'turnover': 8361441280},
#  {'date': '2015-01-12T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 79,
#   'turnover': 2826606328},
#  {'date': '2015-01-12T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 11188047608},
#  {'date': '2015-01-13T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 27,
#   'turnover': 1759000000},
#  {'date': '2015-01-13T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 244881,
#   'turnover': 63076472910},
#  {'date': '2015-01-13T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 384,
#   'turnover': 14649507421},
#  {'date': '2015-01-13T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 79484980331},
#  {'date': '2015-01-14T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 4,
#   'turnover': 258000000},
#  {'date': '2015-01-14T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 308084,
#   'turnover': 70270404850},
#  {'date': '2015-01-14T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 1057,
#   'turnover': 50432611570},
#  {'date': '2015-01-14T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 120961016420},
#  {'date': '2015-01-15T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 4,
#   'turnover': 266000000},
#  {'date': '2015-01-15T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 148968,
#   'turnover': 34967405890},
#  {'date': '2015-01-15T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 217,
#   'turnover': 10052386746},
#  {'date': '2015-01-15T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 45285792636},
#  {'date': '2015-01-16T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 24,
#   'turnover': 1600510000},
#  {'date': '2015-01-16T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 17599,
#   'turnover': 3985443070},
#  {'date': '2015-01-16T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 36,
#   'turnover': 1639620243},
#  {'date': '2015-01-16T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 7225573313},
#  {'date': '2015-01-17T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-01-17T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 73867,
#   'turnover': 17304405210},
#  {'date': '2015-01-17T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 16,
#   'turnover': 764960202},
#  {'date': '2015-01-17T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 18069365412},
#  {'date': '2015-01-18T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-01-18T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 22622,
#   'turnover': 5385609000},
#  {'date': '2015-01-18T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 16,
#   'turnover': 730992506},
#  {'date': '2015-01-18T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 6116601506},
#  {'date': '2015-01-19T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-01-19T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 36422,
#   'turnover': 8537401900},
#  {'date': '2015-01-19T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 25,
#   'turnover': 1121256625},
#  {'date': '2015-01-19T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 9658658525},
#  {'date': '2015-01-20T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-01-20T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 100935,
#   'turnover': 25027205570},
#  {'date': '2015-01-20T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 2,
#   'turnover': 88122498},
#  {'date': '2015-01-20T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 25115328068},
#  {'date': '2015-01-21T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-01-21T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 65834,
#   'turnover': 16308481130},
#  {'date': '2015-01-21T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 91,
#   'turnover': 3978220557},
#  {'date': '2015-01-21T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 20286701687},
#  {'date': '2015-01-22T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-01-22T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 96553,
#   'turnover': 25317852070},
#  {'date': '2015-01-22T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 70,
#   'turnover': 2991095127},
#  {'date': '2015-01-22T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 28308947197},
#  {'date': '2015-01-23T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-01-23T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 42089,
#   'turnover': 10396075700},
#  {'date': '2015-01-23T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 41,
#   'turnover': 1753655723},
#  {'date': '2015-01-23T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 12149731423},
#  {'date': '2015-01-24T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-01-24T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 19874,
#   'turnover': 4942829570},
#  {'date': '2015-01-24T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 403,
#   'turnover': 16842883240},
#  {'date': '2015-01-24T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 21785712810},
#  {'date': '2015-01-25T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-01-25T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 65434,
#   'turnover': 16821219580},
#  {'date': '2015-01-25T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 417,
#   'turnover': 16723659429},
#  {'date': '2015-01-25T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 33544879009},
#  {'date': '2015-01-26T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-01-26T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 324751,
#   'turnover': 96433104860},
#  {'date': '2015-01-26T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 2353,
#   'turnover': 87817955090},
#  {'date': '2015-01-26T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 184251059950},
#  {'date': '2015-01-27T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 6,
#   'turnover': 480000000},
#  {'date': '2015-01-27T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 63719,
#   'turnover': 17062502800},
#  {'date': '2015-01-27T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 76,
#   'turnover': 2831081855},
#  {'date': '2015-01-27T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 20373584655},
#  {'date': '2015-01-28T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 3,
#   'turnover': 240000000},
#  {'date': '2015-01-28T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 93559,
#   'turnover': 23881569420},
#  {'date': '2015-01-28T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 315,
#   'turnover': 12551796170},
#  {'date': '2015-01-28T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 36673365590},
#  {'date': '2015-01-29T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 4,
#   'turnover': 340000000},
#  {'date': '2015-01-29T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 68627,
#   'turnover': 16877030400},
#  {'date': '2015-01-29T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 127,
#   'turnover': 5523513760},
#  {'date': '2015-01-29T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 22740544160},
#  {'date': '2015-01-30T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-01-30T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 141250,
#   'turnover': 34422648720},
#  {'date': '2015-01-30T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 58,
#   'turnover': 2431579662},
#  {'date': '2015-01-30T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 36854228382},
#  {'date': '2015-01-31T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 1,
#   'turnover': 89500000},
#  {'date': '2015-01-31T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 41550,
#   'turnover': 10221102000},
#  {'date': '2015-01-31T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 83,
#   'turnover': 3637564931},
#  {'date': '2015-01-31T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 13948166931},
#  {'date': '2015-02-01T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-02-01T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 128658,
#   'turnover': 29497338500},
#  {'date': '2015-02-01T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 65,
#   'turnover': 3003381276},
#  {'date': '2015-02-01T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 32500719776},
#  {'date': '2015-02-02T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-02-02T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 17331,
#   'turnover': 4228067620},
#  {'date': '2015-02-02T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 8617,
#   'turnover': 7554817772},
#  {'date': '2015-02-02T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 11782885392},
#  {'date': '2015-02-03T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 15,
#   'turnover': 1604010000},
#  {'date': '2015-02-03T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 21857,
#   'turnover': 5439330900},
#  {'date': '2015-02-03T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 20190,
#   'turnover': 20636107458},
#  {'date': '2015-02-03T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 27679448358},
#  {'date': '2015-02-04T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 4,
#   'turnover': 415510000},
#  {'date': '2015-02-04T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 11954,
#   'turnover': 2854837000},
#  {'date': '2015-02-04T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 9974,
#   'turnover': 5416824212},
#  {'date': '2015-02-04T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 8687171212},
#  {'date': '2015-02-05T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 4,
#   'turnover': 396000000},
#  {'date': '2015-02-05T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 11214,
#   'turnover': 2600814030},
#  {'date': '2015-02-05T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 9792,
#   'turnover': 5045496984},
#  {'date': '2015-02-05T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 8042311014},
#  {'date': '2015-02-06T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-02-06T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 19344,
#   'turnover': 4432765590},
#  {'date': '2015-02-06T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 4357,
#   'turnover': 7087070900},
#  {'date': '2015-02-06T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 11519836490},
#  {'date': '2015-02-07T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 1,
#   'turnover': 110000000},
#  {'date': '2015-02-07T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 7611,
#   'turnover': 1799389690},
#  {'date': '2015-02-07T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 3414,
#   'turnover': 2062993948},
#  {'date': '2015-02-07T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 3972383638},
#  {'date': '2015-02-08T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-02-08T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2007,
#   'turnover': 478144350},
#  {'date': '2015-02-08T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 5314,
#   'turnover': 2816813752},
#  {'date': '2015-02-08T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 3294958102},
#  {'date': '2015-02-09T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-02-09T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 6572,
#   'turnover': 1512365300},
#  {'date': '2015-02-09T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 4957,
#   'turnover': 11498128300},
#  {'date': '2015-02-09T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 13010493600},
#  {'date': '2015-02-10T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-02-10T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 9501,
#   'turnover': 2156655000},
#  {'date': '2015-02-10T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 5181,
#   'turnover': 6097603318},
#  {'date': '2015-02-10T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 8254258318},
#  {'date': '2015-02-11T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-02-11T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3111,
#   'turnover': 720399000},
#  {'date': '2015-02-11T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 1033,
#   'turnover': 599058110},
#  {'date': '2015-02-11T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 1319457110},
#  {'date': '2015-02-12T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-02-12T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3405,
#   'turnover': 791888000},
#  {'date': '2015-02-12T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 781,
#   'turnover': 400840303},
#  {'date': '2015-02-12T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 1192728303},
#  {'date': '2015-02-13T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-02-13T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 12235,
#   'turnover': 2969110700},
#  {'date': '2015-02-13T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 2245,
#   'turnover': 2869527461},
#  {'date': '2015-02-13T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 5838638161},
#  {'date': '2015-02-14T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-02-14T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 20160,
#   'turnover': 5158030770},
#  {'date': '2015-02-14T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 5308,
#   'turnover': 4471625657},
#  {'date': '2015-02-14T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 9629656427},
#  {'date': '2015-02-15T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 1,
#   'turnover': 115000000},
#  {'date': '2015-02-15T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 38845,
#   'turnover': 9830875270},
#  {'date': '2015-02-15T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 2949,
#   'turnover': 4834178885},
#  {'date': '2015-02-15T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 14780054155},
#  {'date': '2015-02-16T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-02-16T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 10063,
#   'turnover': 2466057750},
#  {'date': '2015-02-16T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 1583,
#   'turnover': 3904726916},
#  {'date': '2015-02-16T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 6370784666},
#  {'date': '2015-02-17T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 1,
#   'turnover': 105010000},
#  {'date': '2015-02-17T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 5496,
#   'turnover': 1375401090},
#  {'date': '2015-02-17T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 2064,
#   'turnover': 3362684883},
#  {'date': '2015-02-17T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 4843095973},
#  {'date': '2015-02-18T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-02-18T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 11715,
#   'turnover': 2933949920},
#  {'date': '2015-02-18T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 9246,
#   'turnover': 5148146760},
#  {'date': '2015-02-18T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 8082096680},
#  {'date': '2015-02-19T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-02-19T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 6800,
#   'turnover': 1668704000},
#  {'date': '2015-02-19T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 1615,
#   'turnover': 676734105},
#  {'date': '2015-02-19T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 2345438105},
#  {'date': '2015-02-20T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 1,
#   'turnover': 101010000},
#  {'date': '2015-02-20T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 10652,
#   'turnover': 2647345500},
#  {'date': '2015-02-20T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 3769,
#   'turnover': 1913005425},
#  {'date': '2015-02-20T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 4661360925},
#  {'date': '2015-02-21T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-02-21T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 8664,
#   'turnover': 2120485700},
#  {'date': '2015-02-21T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 1000,
#   'turnover': 405684900},
#  {'date': '2015-02-21T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 2526170600},
#  {'date': '2015-02-22T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 1,
#   'turnover': 95300000},
#  {'date': '2015-02-22T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3549,
#   'turnover': 824657970},
#  {'date': '2015-02-22T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 573,
#   'turnover': 1090113324},
#  {'date': '2015-02-22T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 2010071294},
#  {'date': '2015-02-23T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-02-23T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3100,
#   'turnover': 739235000},
#  {'date': '2015-02-23T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 1906,
#   'turnover': 1015499221},
#  {'date': '2015-02-23T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 1754734221},
#  {'date': '2015-02-24T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 1,
#   'turnover': 104500000},
#  {'date': '2015-02-24T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2756,
#   'turnover': 673605040},
#  {'date': '2015-02-24T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 1634,
#   'turnover': 4125379046},
#  {'date': '2015-02-24T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 4903484086},
#  {'date': '2015-02-25T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 1,
#   'turnover': 103500000},
#  {'date': '2015-02-25T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 2500,
#   'turnover': 609420000},
#  {'date': '2015-02-25T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 5000,
#   'turnover': 2103512500},
#  {'date': '2015-02-25T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 2816432500},
#  {'date': '2015-02-26T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 12,
#   'turnover': 1133500000},
#  {'date': '2015-02-26T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1500,
#   'turnover': 359405000},
#  {'date': '2015-02-26T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 2503,
#   'turnover': 1181650891},
#  {'date': '2015-02-26T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 2674555891},
#  {'date': '2015-02-27T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 18,
#   'turnover': 1659420000},
#  {'date': '2015-02-27T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 69734,
#   'turnover': 17740679310},
#  {'date': '2015-02-27T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 9421,
#   'turnover': 10444325895},
#  {'date': '2015-02-27T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 29844425205},
#  {'date': '2015-02-28T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-02-28T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 500,
#   'turnover': 131500000},
#  {'date': '2015-02-28T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 3279,
#   'turnover': 2224730272},
#  {'date': '2015-02-28T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 2356230272},
#  {'date': '2015-03-01T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 2,
#   'turnover': 191000000},
#  {'date': '2015-03-01T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 23385,
#   'turnover': 6134491000},
#  {'date': '2015-03-01T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 6062,
#   'turnover': 4764308309},
#  {'date': '2015-03-01T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 11089799309},
#  {'date': '2015-03-02T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-03-02T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 38726,
#   'turnover': 10916812420},
#  {'date': '2015-03-02T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 11653,
#   'turnover': 9255861268},
#  {'date': '2015-03-02T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 20172673688},
#  {'date': '2015-03-03T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 1,
#   'turnover': 90000000},
#  {'date': '2015-03-03T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 27344,
#   'turnover': 7957919390},
#  {'date': '2015-03-03T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 10513,
#   'turnover': 9107199758},
#  {'date': '2015-03-03T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 17155119148},
#  {'date': '2015-03-04T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-03-04T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 19548,
#   'turnover': 5417115470},
#  {'date': '2015-03-04T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 10684,
#   'turnover': 22474474588},
#  {'date': '2015-03-04T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 27891590058},
#  {'date': '2015-03-05T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-03-05T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3932,
#   'turnover': 1084551210},
#  {'date': '2015-03-05T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 4542,
#   'turnover': 12011336744},
#  {'date': '2015-03-05T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 13095887954},
#  {'date': '2015-03-06T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-03-06T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3521,
#   'turnover': 994462230},
#  {'date': '2015-03-06T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 2252,
#   'turnover': 2664923403},
#  {'date': '2015-03-06T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 3659385633},
#  {'date': '2015-03-07T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-03-07T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1131,
#   'turnover': 321920000},
#  {'date': '2015-03-07T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 1334,
#   'turnover': 951179372},
#  {'date': '2015-03-07T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 1273099372},
#  {'date': '2015-03-08T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-03-08T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 1000,
#   'turnover': 286500000},
#  {'date': '2015-03-08T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 2506,
#   'turnover': 1122795906},
#  {'date': '2015-03-08T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 1409295906},
#  {'date': '2015-03-09T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-03-09T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 23896,
#   'turnover': 7087924450},
#  {'date': '2015-03-09T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 5230,
#   'turnover': 8078510778},
#  {'date': '2015-03-09T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 15166435228},
#  {'date': '2015-03-10T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-03-10T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 31604,
#   'turnover': 9611930680},
#  {'date': '2015-03-10T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 11024,
#   'turnover': 11930491130},
#  {'date': '2015-03-10T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 21542421810},
#  {'date': '2015-03-11T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-03-11T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 6450,
#   'turnover': 1950049850},
#  {'date': '2015-03-11T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 5410,
#   'turnover': 5849123047},
#  {'date': '2015-03-11T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 7799172897},
#  {'date': '2015-03-12T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-03-12T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
# ...
#   'currency': 'XBt',
#   'volume': 2287,
#   'turnover': 11721315210},
#  {'date': '2015-07-17T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 16969681440},
#  {'date': '2015-07-18T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 20,
#   'turnover': 66800000},
#  {'date': '2015-07-18T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 7451,
#   'turnover': 2134741000},
#  {'date': '2015-07-18T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 1784,
#   'turnover': 1938467154},
#  {'date': '2015-07-18T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 4140008154},
#  {'date': '2015-07-19T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 76,
#   'turnover': 170970000},
#  {'date': '2015-07-19T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 3010,
#   'turnover': 858417500},
#  {'date': '2015-07-19T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 1601,
#   'turnover': 1550110854},
#  {'date': '2015-07-19T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 2579498354},
#  {'date': '2015-07-20T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 36,
#   'turnover': 64690000},
#  {'date': '2015-07-20T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 8842,
#   'turnover': 2514574320},
#  {'date': '2015-07-20T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 1155,
#   'turnover': 1684357567},
#  {'date': '2015-07-20T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 4263621887},
#  {'date': '2015-07-21T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 31,
#   'turnover': 55100000},
#  {'date': '2015-07-21T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 21149,
#   'turnover': 6094010000},
#  {'date': '2015-07-21T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 2588,
#   'turnover': 1952009669},
#  {'date': '2015-07-21T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 8101119669},
#  {'date': '2015-07-22T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 0,
#   'turnover': 0},
#  {'date': '2015-07-22T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 19750,
#   'turnover': 5664192500},
#  {'date': '2015-07-22T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 3296,
#   'turnover': 1586473128},
#  {'date': '2015-07-22T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 7250665628},
#  {'date': '2015-07-23T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 42,
#   'turnover': 56900000},
#  {'date': '2015-07-23T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 17459,
#   'turnover': 4983376480},
#  {'date': '2015-07-23T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 1072,
#   'turnover': 1028669213},
#  {'date': '2015-07-23T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 6068945693},
#  {'date': '2015-07-24T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 34,
#   'turnover': 72420000},
#  {'date': '2015-07-24T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 40719,
#   'turnover': 12034589860},
#  {'date': '2015-07-24T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 2506,
#   'turnover': 7103928740},
#  {'date': '2015-07-24T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 19210938600},
#  {'date': '2015-07-25T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 10,
#   'turnover': 15700000},
#  {'date': '2015-07-25T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 16715,
#   'turnover': 5066800500},
#  {'date': '2015-07-25T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 2430,
#   'turnover': 1780991232},
#  {'date': '2015-07-25T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 6863491732},
#  {'date': '2015-07-26T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 20,
#   'turnover': 36800000},
#  {'date': '2015-07-26T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 27792,
#   'turnover': 8266157460},
#  {'date': '2015-07-26T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 3016,
#   'turnover': 4246093560},
#  {'date': '2015-07-26T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 12549051020},
#  {'date': '2015-07-27T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 59,
#   'turnover': 114770000},
#  {'date': '2015-07-27T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 145639,
#   'turnover': 44540440760},
#  {'date': '2015-07-27T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 2391,
#   'turnover': 5235147725},
#  {'date': '2015-07-27T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 49890358485},
#  {'date': '2015-07-28T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 26,
#   'turnover': 61160000},
#  {'date': '2015-07-28T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 174069,
#   'turnover': 54428232740},
#  {'date': '2015-07-28T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 2868,
#   'turnover': 6516589685},
#  {'date': '2015-07-28T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 61005982425},
#  {'date': '2015-07-29T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 33,
#   'turnover': 99610000},
#  {'date': '2015-07-29T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 135789,
#   'turnover': 41518148290},
#  {'date': '2015-07-29T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 1509,
#   'turnover': 12863797856},
#  {'date': '2015-07-29T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 54481556146},
#  {'date': '2015-07-30T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 8,
#   'turnover': 16640000},
#  {'date': '2015-07-30T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 67778,
#   'turnover': 20383797230},
#  {'date': '2015-07-30T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 1581,
#   'turnover': 3357597127},
#  {'date': '2015-07-30T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 23758034357},
#  {'date': '2015-07-31T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 21,
#   'turnover': 65580000},
#  {'date': '2015-07-31T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 155700,
#   'turnover': 45536187060},
#  {'date': '2015-07-31T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 5928,
#   'turnover': 23401586703},
#  {'date': '2015-07-31T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 69003353763},
#  {'date': '2015-08-01T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 4,
#   'turnover': 7290000},
#  {'date': '2015-08-01T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 101780,
#   'turnover': 30181034900},
#  {'date': '2015-08-01T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 6943,
#   'turnover': 3138333011},
#  {'date': '2015-08-01T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 33326657911},
#  {'date': '2015-08-02T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 1,
#   'turnover': 2060000},
#  {'date': '2015-08-02T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 97761,
#   'turnover': 28880842230},
#  {'date': '2015-08-02T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 3328,
#   'turnover': 1465591568},
#  {'date': '2015-08-02T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 30348493798},
#  {'date': '2015-08-03T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 3,
#   'turnover': 8850000},
#  {'date': '2015-08-03T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 91175,
#   'turnover': 27714748900},
#  {'date': '2015-08-03T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 2110,
#   'turnover': 2692584241},
#  {'date': '2015-08-03T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 30416183141},
#  {'date': '2015-08-04T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 32,
#   'turnover': 60400000},
#  {'date': '2015-08-04T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 39364,
#   'turnover': 11898227420},
#  {'date': '2015-08-04T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 304,
#   'turnover': 245530976},
#  {'date': '2015-08-04T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 12204158396},
#  {'date': '2015-08-05T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 57,
#   'turnover': 93060000},
#  {'date': '2015-08-05T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 34048,
#   'turnover': 10149128760},
#  {'date': '2015-08-05T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 643,
#   'turnover': 1791498936},
#  {'date': '2015-08-05T00:00:00.000Z',
#   'rootSymbol': 'XLT',
#   'currency': 'XBt',
#   'volume': 4952,
#   'turnover': 2168924000},
#  {'date': '2015-08-05T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 14202611696},
#  {'date': '2015-08-06T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 89,
#   'turnover': 141150000},
#  {'date': '2015-08-06T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 66066,
#   'turnover': 19509926330},
#  {'date': '2015-08-06T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 1103,
#   'turnover': 10307298360},
#  {'date': '2015-08-06T00:00:00.000Z',
#   'rootSymbol': 'XLT',
#   'currency': 'XBt',
#   'volume': 7922,
#   'turnover': 3323693000},
#  {'date': '2015-08-06T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 33282067690},
#  {'date': '2015-08-07T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 29,
#   'turnover': 80350000},
#  {'date': '2015-08-07T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 1402,
#   'turnover': 1225230000},
#  {'date': '2015-08-07T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 52789,
#   'turnover': 15350183730},
#  {'date': '2015-08-07T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 1804,
#   'turnover': 16431506273},
#  {'date': '2015-08-07T00:00:00.000Z',
#   'rootSymbol': 'XLT',
#   'currency': 'XBt',
#   'volume': 37798,
#   'turnover': 15724603700},
#  {'date': '2015-08-07T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 48811873703},
#  {'date': '2015-08-08T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 31,
#   'turnover': 55700000},
#  {'date': '2015-08-08T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 22543,
#   'turnover': 5988678000},
#  {'date': '2015-08-08T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 206030,
#   'turnover': 58797810270},
#  {'date': '2015-08-08T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 4939,
#   'turnover': 9262271243},
#  {'date': '2015-08-08T00:00:00.000Z',
#   'rootSymbol': 'XLT',
#   'currency': 'XBt',
#   'volume': 17609,
#   'turnover': 7123460400},
#  {'date': '2015-08-08T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 81227919913},
#  {'date': '2015-08-09T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 32,
#   'turnover': 100470000},
#  {'date': '2015-08-09T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 13082,
#   'turnover': 3269576000},
#  {'date': '2015-08-09T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 72516,
#   'turnover': 20063157300},
#  {'date': '2015-08-09T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 1838,
#   'turnover': 5880414456},
#  {'date': '2015-08-09T00:00:00.000Z',
#   'rootSymbol': 'XLT',
#   'currency': 'XBt',
#   'volume': 10929,
#   'turnover': 4246940500},
#  {'date': '2015-08-09T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 33560558256},
#  {'date': '2015-08-10T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 2,
#   'turnover': 3960000},
#  {'date': '2015-08-10T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 5698,
#   'turnover': 1269683000},
#  {'date': '2015-08-10T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 61811,
#   'turnover': 17421742570},
#  {'date': '2015-08-10T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 947,
#   'turnover': 6216499055},
#  {'date': '2015-08-10T00:00:00.000Z',
#   'rootSymbol': 'XLT',
#   'currency': 'XBt',
#   'volume': 4902,
#   'turnover': 2225954800},
#  {'date': '2015-08-10T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 27137839425},
#  {'date': '2015-08-11T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 5,
#   'turnover': 7850000},
#  {'date': '2015-08-11T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 27231,
#   'turnover': 9048224000},
#  {'date': '2015-08-11T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 81002,
#   'turnover': 22835196370},
#  {'date': '2015-08-11T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 2541,
#   'turnover': 2896653561},
#  {'date': '2015-08-11T00:00:00.000Z',
#   'rootSymbol': 'XLT',
#   'currency': 'XBt',
#   'volume': 8102,
#   'turnover': 3299108500},
#  {'date': '2015-08-11T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 38087032431},
#  {'date': '2015-08-12T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 17,
#   'turnover': 32300000},
#  {'date': '2015-08-12T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 18808,
#   'turnover': 7289986000},
#  {'date': '2015-08-12T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 87199,
#   'turnover': 24613211520},
#  {'date': '2015-08-12T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 2498,
#   'turnover': 1593718523},
#  {'date': '2015-08-12T00:00:00.000Z',
#   'rootSymbol': 'XLT',
#   'currency': 'XBt',
#   'volume': 4335,
#   'turnover': 1772210000},
#  {'date': '2015-08-12T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 35301426043},
#  {'date': '2015-08-13T00:00:00.000Z',
#   'rootSymbol': 'BVOL',
#   'currency': 'XBt',
#   'volume': 10,
#   'turnover': 18300000},
#  {'date': '2015-08-13T00:00:00.000Z',
#   'rootSymbol': 'ETH',
#   'currency': 'XBt',
#   'volume': 26743,
#   'turnover': 14873611000},
#  {'date': '2015-08-13T00:00:00.000Z',
#   'rootSymbol': 'XBT',
#   'currency': 'XBt',
#   'volume': 114594,
#   'turnover': 32063862760},
#  {'date': '2015-08-13T00:00:00.000Z',
#   'rootSymbol': 'XBU',
#   'currency': 'XBt',
#   'volume': 847,
#   'turnover': 579994663},
#  {'date': '2015-08-13T00:00:00.000Z',
#   'rootSymbol': 'XLT',
#   'currency': 'XBt',
#   'volume': 11512,
#   'turnover': 4481697800},
#  {'date': '2015-08-13T00:00:00.000Z',
#   'rootSymbol': 'Total',
#   'currency': 'XBt',
#   'volume': None,
#   'turnover': 52017466223},
#  ...]

# %% [markdown]
# ## 1. Download historical data

# %%
now = datetime.datetime.now().isoformat()
bitmex_params = [#('funding',{'symbol':'XBTUSD','count':'100','reverse':'false','start':'0','endTime':now}),    # funding_rate
                 #('liquidation',{}),
                 ('stats/history',{}),    # volume
                 ('stats',{}),    # openInterest, openValue "rootSymbol" -- call "XBT" and "ETH"
                ]

# Initialise historical data. This will not overwrite files of the same name in the target folder so be sure to delete them first if they exist.
def get_historical_bitmex(bitmex_params):
    sample = 'sample'
    for item in bitmex_params:
        endpoint, params_dict = item
        filepath = 'data/Bitmex/' + endpoint + '.csv'
        
        if os.path.isfile(filepath):
            print('Please delete or rename previous file of same name.')
            raise
        
        while sample!='':
            api_call_url = 'https://www.bitmex.com/api/v1/' + endpoint + '?_format=csv'
            # Check if any parameters are applied
            if bool(params_dict):
                for param in params_dict:
                    api_call_url += '&' + param + '=' + params_dict[param] 
            r = requests.get(api_call_url)
            if r.status_code != 200:
                print(r.status_code)
                return
            csv_list = r.text.split('\n')
            
            # Create a new file only if one does not exist, and append the headers
            if not os.path.isfile(filepath):
                with open(filepath, 'w') as csv_file:
                    for row in csv_list[0]:
                        csv_file.write(row)
            
            with open(filepath, 'a') as csv_file:
                # Append the data, but skip the headers
                for row in csv_list[1:]:
                    csv_file.write('\n'+row)
            
            params_dict['start'] = str(int(params_dict['start']) + int(params_dict['count']))
            sample = r.text[:5]

# %%
get_historical_bitmex(bitmex_params)

# %% [markdown]
# ## 2. Update data

# %%
# Ref: https://www.bitmex.com/api/explorer/
# Parameters for each API call. All variables must be in string format
bitmex_params = [('funding',{'symbol':'XBTUSD','count':'100','reverse':'false','start':'0'}),
                 #('liquidation',{}),
                ]

def update_bitmex(bitmex_params):
    # Update data from timestamp of last entry in file
    for item in bitmex_params:
        endpoint, params_dict = item
        filepath = 'data/Bitmex/' + endpoint + '.csv'
        api_call_url = 'https://www.bitmex.com/api/v1/' + endpoint + '?_format=csv'
        
        # Check if any parameters are applied
        if bool(params_dict):
            
            # Check for timestamp of last entry
            timestamp_df = pd.read_csv(filepath, usecols=['timestamp'])
            params_dict['startTime'] = timestamp_df.values[-1][0]
            params_dict['start'] = '1'
            
            for param in params_dict:
                api_call_url += '&' + param + '=' + params_dict[param] 

        r = requests.get(api_call_url)
        if r.status_code != 200:
            print(r.status_code)
            break
        
        csv_list = r.text.split('\n')
        print(csv_list)
        with open(filepath, 'a') as csv_file:
            # Append the data, but skip the headers
            for row in csv_list[1:]:
                csv_file.write(row + '\n')

# %%
update_bitmex(bitmex_params)
# Out:
# ['"timestamp","symbol","fundingInterval","fundingRate","fundingRateDaily"', '"2019-10-03T12:00:00.000Z","XBTUSD","2000-01-01T08:00:00.000Z",0.0001,0.00030000000000000003', '"2019-10-03T20:00:00.000Z","XBTUSD","2000-01-01T08:00:00.000Z",-0.000133,-0.00039900000000000005', '"2019-10-04T04:00:00.000Z","XBTUSD","2000-01-01T08:00:00.000Z",-0.000183,-0.000549']

# %% [markdown]
# # Coinmetrics
# https://docs.coinmetrics.io/api/v2/

# %% [markdown]
# ## a) Get historical data

# %%
# Get full data
metrics = 'AdrActCnt,BlkCnt,BlkSizeByte,BlkSizeMeanByte,CapMVRVCur,CapMrktCurUSD,CapRealUSD,DiffMean,FeeMeanNtv,FeeMeanUSD,FeeMedNtv,FeeMedUSD,FeeTotNtv,FeeTotUSD,IssContNtv,IssContPctAnn,IssContUSD,IssTotNtv,IssTotUSD,NVTAdj,NVTAdj90,PriceBTC,PriceUSD,ROI1yr,ROI30d,SplyCur,TxCnt,TxTfrCnt,TxTfrValAdjNtv,TxTfrValAdjUSD,TxTfrValMeanNtv,TxTfrValMeanUSD,TxTfrValMedNtv,TxTfrValMedUSD,TxTfrValNtv,TxTfrValUSD,VtyDayRet180d,VtyDayRet30d,VtyDayRet60d'
r = requests.get('https://community-api.coinmetrics.io/v2/assets/btc/metricdata.csv?metrics='+ metrics)
if r.status_code != 200:
    print(r.status_code)
    raise

# %%
csv_list = r.text.split('\n')
with open('data/Coinmetrics/Coinmetrics_btc.csv', 'w') as csv_file:
    for row in csv_list:
        csv_file.write(row)

# %% [markdown]
# ## b) Update daily

# %%
# Get timestamp of last entry
filepath = 'data/Coinmetrics/Coinmetrics_btc.csv'
timestamp_df = pd.read_csv(filepath, usecols=['time'])
timestamp_df = timestamp_df.astype('datetime64')
timestamp_df.values[-1][0]+1
start_time = str(timestamp_df.values[-1][0]+10000000)
start = '&start=' + str(start_time)[:23] + 'Z'

metrics = 'AdrActCnt,BlkCnt,BlkSizeByte,BlkSizeMeanByte,CapMVRVCur,CapMrktCurUSD,CapRealUSD,DiffMean,FeeMeanNtv,FeeMeanUSD,FeeMedNtv,FeeMedUSD,FeeTotNtv,FeeTotUSD,IssContNtv,IssContPctAnn,IssContUSD,IssTotNtv,IssTotUSD,NVTAdj,NVTAdj90,PriceBTC,PriceUSD,ROI1yr,ROI30d,SplyCur,TxCnt,TxTfrCnt,TxTfrValAdjNtv,TxTfrValAdjUSD,TxTfrValMeanNtv,TxTfrValMeanUSD,TxTfrValMedNtv,TxTfrValMedUSD,TxTfrValNtv,TxTfrValUSD,VtyDayRet180d,VtyDayRet30d,VtyDayRet60d' #,TxTfr
r = requests.get('https://community-api.coinmetrics.io/v2/assets/btc/metricdata.csv?metrics='+ metrics + start)
if r.status_code != 200:
    print(r.status_code)
    raise
csv_list = r.text.split('\n')
with open(filepath, 'a') as csv_file:
    for row in csv_list[1:]:
        csv_file.write(row)

# %% [markdown]
# # Quandl
# https://www.quandl.com/tools/python

# %% [markdown]
# # Coinfarm

# %%
from requests_html import HTMLSession
from bs4 import BeautifulSoup

# %%
# create an HTML Session object
session = HTMLSession()
# Use the object above to connect to needed webpage
resp = session.get("https://coinfarm.online/position/position_realtime.asp")
# Run JavaScript code on webpage
resp.html.render(sleep=5)
soup = BeautifulSoup(resp.html.html, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-d37eee96dbb5> in <module>
#       4 resp = session.get("https://coinfarm.online/position/position_realtime.asp")
#       5 # Run JavaScript code on webpage
# ----> 6 resp.html.render(sleep=5)
#       7 soup = BeautifulSoup(resp.html.html, 'html.parser')
#
# ~\Miniconda3\envs\venture_256\lib\site-packages\requests_html.py in render(self, retries, script, wait, scrolldown, sleep, reload, timeout, keep_page)
#     584         """
#     585
# --> 586         self.browser = self.session.browser  # Automatically create a event loop and browser
#     587         content = None
#     588
#
# ~\Miniconda3\envs\venture_256\lib\site-packages\requests_html.py in browser(self)
#     727             self.loop = asyncio.get_event_loop()
#     728             if self.loop.is_running():
# --> 729                 raise RuntimeError("Cannot use HTMLSession within an existing event loop. Use AsyncHTMLSession instead.")
#     730             self._browser = self.loop.run_until_complete(super().browser)
#     731         return self._browser
#
# RuntimeError: Cannot use HTMLSession within an existing event loop. Use AsyncHTMLSession instead.

# %%
soup.body.center.find('table', {'style':"background:#253440;"},
                      recursive=False).find('tbody', recursive=False).find('tr',
                                                                           recursive=False).find('td',{"style":"background:url('/public/bg_2.png') no-repeat ;"}).table.tbody.find_all('tr',recursive=False)[6]
# row = td_tag.table.tbody.find_all('tr',recursive=False)[6]
# header = row.find_all('td', recursive=False)[0].table.tbody.tr

# %%
with open('coinfarm.txt', 'r', encoding='utf-8') as html_file:
    html_text = str(html_file)

# %%
html_text
# Out:
# "<_io.TextIOWrapper name='coinfarm.txt' mode='r' encoding='utf-8'>"

# %%
coinfarm_bs = BeautifulSoup(html_text, 'html.parser')

# %%
coinfarm_bs.body.center.find('table', 
                              {'style':"background:#253440;"}, 
                              recursive=False).find('tbody', 
                                                    recursive=False).find('tr',
                                                                          recursive=False).find('td',
                                                                                                recursive=False)
#/html/body/center/table/tbody/tr/td/table[2]/tbody/tr/td/table/tbody/tr[7]/td/table/tbody/tr/td[3]/span
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-333e111e2724> in <module>
# ----> 1 coinfarm_bs.body.center.find('table',
#       2                               {'style':"background:#253440;"},
#       3                               recursive=False).find('tbody',
#       4                                                     recursive=False).find('tr',
#       5                                                                           recursive=False).find('td',
#
# AttributeError: 'NoneType' object has no attribute 'center'

# %% [markdown]
# # Glassnode

# %%
variables = ['Sopr', 'aSopr', 'Cdd', 'AverageDormancy'. 'AverageDormancySupplyAdjusted']
for var in variables:
    r = requests.get('https://studio.glassnode.com/metrics?a=BTC&m=indicators.' + var)
    if r.status_code != 200:
        print(r.status_code)
        raise
    r.text

# %% [markdown]
# # Deribit
# https://docs.deribit.com/v2/?python#methods

# %%
r.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-166-52b7ec8d97cc> in <module>
# ----> 1 r.json()
#
# ~\Miniconda3\envs\venture_256\lib\site-packages\requests\models.py in json(self, **kwargs)
#     895                     # used.
#     896                     pass
# --> 897         return complexjson.loads(self.text, **kwargs)
#     898
#     899     @property
#
# ~\Miniconda3\envs\venture_256\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\Miniconda3\envs\venture_256\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\Miniconda3\envs\venture_256\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
with open('data.json', 'w') as f:
    json.dump(data, f)

# %%
def upload_file(file_name, bucket, object_name=None):
    """Upload a file to an S3 bucket

    :param file_name: File to upload
    :param bucket: Bucket to upload to
    :param object_name: S3 object name. If not specified then file_name is used
    :return: True if file was uploaded, else False
    """

    # If S3 object_name was not specified, use file_name
    if object_name is None:
        object_name = file_name

    # Upload the file
    s3_client = boto3.client('s3')
    try:
        response = s3_client.upload_file(file_name, bucket, object_name)
    except ClientError as e:
        logging.error(e)
        return False
    return True

# %%
# Let's use Amazon S3
s3 = boto3.resource('s3')
# Print out bucket names
for bucket in s3.buckets.all():
    print(bucket.name)
# Out:
# your-s3-bucket-name-deeloon

# %%
data = open('data.json', 'rb')
s3.Bucket('your-s3-bucket-name-deeloon').put_object(Key='data.json', Body=data)
# Out:
# s3.Object(bucket_name='your-s3-bucket-name-deeloon', key='data.json')
